# %%
import pandas as pd

# %%
file_path = "../Resources/park_visitation.csv"
park_visitation_df = pd.read_csv(file_path)
park_visitation_df.head()
# Out:
#   Created By  Measure Selector                  Year  Date Edit  \
# 0     Legacy                 1  1/1/1904 12:00:00 AM  4/22/2015
# 1     Legacy                 1  1/1/1941 12:00:00 AM  4/22/2015
# 2     Legacy                 1  1/1/1961 12:00:00 AM  4/22/2015
# 3     Legacy                 1  1/1/1935 12:00:00 AM  4/22/2015
# 4     Legacy                 1  1/1/1982 12:00:00 AM  4/22/2015
#
#                                            ScrapeURL  \
# 0  https://irma.nps.gov/Stats/SSRSReports/Park%20...
# 1  https://irma.nps.gov/Stats/SSRSReports/Park%20...
# 2  https://irma.nps.gov/Stats/SSRSReports/Park%20...
# 3  https://irma.nps.gov/Stats/SSRSReports/Park%20...
# 4  https://irma.nps.gov/Stats/SSRSReports/Park%20...
#
#                                            GIS Notes  Gnis Id      Geometry  \
# 0  LEGACY: contact allen_mccoy@nps.gov for additi...  1163670       POLYGON
# 1  LEGACY: contact allen_mccoy@nps.gov for additi...  1531834  MULTIPOLYGON
# 2  LEGACY: contact allen_mccoy@nps.gov for additi...  2055170  MULTIPOLYGON
# 3  LEGACY: contact allen_mccoy@nps.gov for additi...  1530459  MULTIPOLYGON
# 4  LEGACY: contact denise_kamradt@nps.gov for add...   277263       POLYGON
#
#   Metadata  Number of Records                Parkname Region State Unit Code  \
# 0      NaN                  1             Crater Lake     PW    OR      CRLA
# 1      NaN                  1          Lake Roosevelt     PW    WA      LARO
# 2      NaN                  1         Lewis and Clark     PW    WA      LEWI
# 3      NaN                  1                 Olympic     PW    WA      OLYM
# 4      NaN                  1  Santa Monica Mountains     PW    CA      SAMO
#
#                                          Unit Name                 Unit Type  \
# 0                        Crater Lake National Park             National Park
# 1          Lake Roosevelt National Recreation Area  National Recreation Area
# 2         Lewis and Clark National Historical Park  National Historical Park
# 3                            Olympic National Park             National Park
# 4  Santa Monica Mountains National Recreation Area  National Recreation Area
#
#    Visitors YearRaw
# 0    1500.0    1904
# 1       0.0    1941
# 2   69000.0    1961
# 3    2200.0    1935
# 4  468144.0    1982

# %%
# Before reading in the species csv: I found an error while importing the clean dataset into SQL on line 30775
# There was an open quotation mark without the closing pair - it was causing several rows to be read as one value
# I viewed the file in a notepad and deleted the extraneous quotation mark

# %%
species_path = "../Resources/species.csv"
species_df = pd.read_csv(species_path)
species_df.head()
# Out:
#   Species ID             Park Name Category         Order    Family  \
# 0  ACAD-1000  Acadia National Park   Mammal  Artiodactyla  Cervidae
# 1  ACAD-1001  Acadia National Park   Mammal  Artiodactyla  Cervidae
# 2  ACAD-1002  Acadia National Park   Mammal     Carnivora   Canidae
# 3  ACAD-1003  Acadia National Park   Mammal     Carnivora   Canidae
# 4  ACAD-1004  Acadia National Park   Mammal     Carnivora   Canidae
#
#           Scientific Name                                       Common Names  \
# 0             Alces alces                                              Moose
# 1  Odocoileus virginianus  Northern White-Tailed Deer, Virginia Deer, Whi...
# 2           Canis latrans                             Coyote, Eastern Coyote
# 3             Canis lupus        Eastern Timber Wolf, Gray Wolf, Timber Wolf
# 4           Vulpes vulpes  Black Fox, Cross Fox, Eastern Red Fox, Fox, Re...
#
#   Record Status     Occurrence  Nativeness Abundance Seasonality  \
# 0      Approved        Present      Native      Rare    Resident
# 1      Approved        Present      Native  Abundant         NaN
# 2      Approved        Present  Not Native    Common         NaN
# 3      Approved  Not Confirmed      Native       NaN         NaN
# 4      Approved        Present     Unknown    Common     Breeder
#
#   Conservation Status Unnamed: 13
# 0                 NaN         NaN
# 1                 NaN         NaN
# 2  Species of Concern         NaN
# 3          Endangered         NaN
# 4                 NaN         NaN

# %%
clean_species_df = species_df[['Park Name', 'Category', 'Common Names', 'Abundance', 'Conservation Status']]
clean_species_df
# Out:
#                    Park Name        Category  \
# 0       Acadia National Park          Mammal
# 1       Acadia National Park          Mammal
# 2       Acadia National Park          Mammal
# 3       Acadia National Park          Mammal
# 4       Acadia National Park          Mammal
# ...                      ...             ...
# 119254    Zion National Park  Vascular Plant
# 119255    Zion National Park  Vascular Plant
# 119256    Zion National Park  Vascular Plant
# 119257    Zion National Park  Vascular Plant
# 119258    Zion National Park  Vascular Plant
#
#                                              Common Names Abundance  \
# 0                                                   Moose      Rare
# 1       Northern White-Tailed Deer, Virginia Deer, Whi...  Abundant
# 2                                  Coyote, Eastern Coyote    Common
# 3             Eastern Timber Wolf, Gray Wolf, Timber Wolf       NaN
# 4       Black Fox, Cross Fox, Eastern Red Fox, Fox, Re...    Common
# ...                                                   ...       ...
# 119254                                Cut-Leaf Nightshade  Uncommon
# 119255                                       Canyon Grape  Uncommon
# 119256                                         Wine Grape  Uncommon
# 119257                                      Creosote Bush      Rare
# 119258                                      Puncture Vine  Uncommon
#
#        Conservation Status
# 0                      NaN
# 1                      NaN
# 2       Species of Concern
# 3               Endangered
# 4                      NaN
# ...                    ...
# 119254                 NaN
# 119255                 NaN
# 119256                 NaN
# 119257                 NaN
# 119258                 NaN
#
# [119259 rows x 5 columns]

# %%
clean_species_df = clean_species_df.rename(columns = {"Park Name": "national_park"}).sort_values('national_park')
clean_species_df['national_park'].unique()
clean_species_df = clean_species_df.rename(columns={'Category': 'category', 'Common Names': 'animal_name', \
                                 'Abundance': 'abundance', 'Conservation Status': 'conservation_status'})

# %%
clean_species_df
# Out:
#                national_park        category             animal_name  \
# 0       Acadia National Park          Mammal                   Moose
# 1146    Acadia National Park  Vascular Plant        Northern Firmoss
# 1145    Acadia National Park  Vascular Plant        Shining Clubmoss
# 1144    Acadia National Park  Vascular Plant         Alpine Clubmoss
# 1143    Acadia National Park  Vascular Plant             Groundcedar
# ...                      ...             ...                     ...
# 118054    Zion National Park  Vascular Plant        Dune Rabbitbrush
# 118053    Zion National Park  Vascular Plant   Whitestem Rabbitbrush
# 118052    Zion National Park  Vascular Plant  Smoothseed Rabbitbrush
# 118134    Zion National Park  Vascular Plant       Prairie Sunflower
# 119258    Zion National Park  Vascular Plant           Puncture Vine
#
#        abundance conservation_status
# 0           Rare                 NaN
# 1146         NaN                 NaN
# 1145         NaN                 NaN
# 1144         NaN                 NaN
# 1143    Uncommon                 NaN
# ...          ...                 ...
# 118054       NaN                 NaN
# 118053  Uncommon                 NaN
# 118052  Uncommon                 NaN
# 118134  Uncommon                 NaN
# 119258  Uncommon                 NaN
#
# [119259 rows x 5 columns]

# %%
clean_species_df.describe()
# Out:
#                               national_park        category animal_name  \
# count                                119259          119259      119259
# unique                                   56              14       35825
# top     Great Smoky Mountains National Park  Vascular Plant        None
# freq                                   6623           65221       27147
#
#        abundance conservation_status
# count      76317                4718
# unique         8                  11
# top      Unknown  Species of Concern
# freq       28119                3843

# %%
# no longer a problem

# problem1 = clean_species_df.iloc[31277,:]
# problem1

# %%
# clean_species_df = clean_species_df.replace('"Tropical"', 'Tropical', regex=True)

# %%
# no longer a problem after fixing csv

# problem2 = clean_species_df.iloc[30769,:]
# problem2

# %%
clean_species_df['abundance'].value_counts()
# Out:
# Unknown       28119
# Uncommon      18780
# Common        12917
# Rare          10770
# Occasional     3316
# Abundant       2365
# Native           40
# Not Native       10
# Name: abundance, dtype: int64

# %%
clean_species_df['category'].value_counts()
# Out:
# Vascular Plant         65221
# Bird                   14612
# Insect                 14349
# Fungi                   6203
# Nonvascular Plant       4278
# Fish                    3956
# Mammal                  3867
# Invertebrate            1566
# Reptile                 1343
# Algae                    976
# Slug/Snail               787
# Spider/Scorpion          776
# Amphibian                743
# Crab/Lobster/Shrimp      582
# Name: category, dtype: int64

# %%
clean_species_df['conservation_status'].value_counts()
# Out:
# Species of Concern     3843
# Endangered              374
# Under Review            194
# Threatened              184
# In Recovery              77
# Proposed Endangered      24
# Breeder                   7
# Proposed Threatened       7
# Resident                  5
# Migratory                 2
# Extinct                   1
# Name: conservation_status, dtype: int64

# %%
extinct = clean_species_df.loc[clean_species_df['conservation_status'] == 'Extinct']
extinct
# Out:
#                        national_park category animal_name abundance  \
# 23237  Cuyahoga Valley National Park     Fish   Blue Pike       NaN
#
#       conservation_status
# 23237             Extinct

# %%
endangered = clean_species_df.loc[clean_species_df['conservation_status'] == 'Endangered']
endangered.head()
# Out:
#              national_park category  \
# 3     Acadia National Park   Mammal
# 166   Acadia National Park     Bird
# 477   Acadia National Park     Fish
# 1935  Arches National Park     Bird
# 1779  Arches National Park     Bird
#
#                                       animal_name   abundance  \
# 3     Eastern Timber Wolf, Gray Wolf, Timber Wolf         NaN
# 166                                 Eskimo Curlew         NaN
# 477            Atlantic Salmon, Landlocked Salmon    Uncommon
# 1935                  Southwest Willow Flycatcher         NaN
# 1779                            California Condor  Occasional
#
#      conservation_status
# 3             Endangered
# 166           Endangered
# 477           Endangered
# 1935          Endangered
# 1779          Endangered

# %%
clean_species_df['animal_name'].value_counts()
# Out:
# None                                     27147
# Brachythecium Moss                          75
# Kentucky Bluegrass                          58
# Lichen                                      57
# Wilson's Warbler                            57
#                                          ...
# Hooded Ladies' Tresses                       1
# Sierra False Coolwort                        1
# Roundhead Rush                               1
# Evergreen Sumac, Mearn Sumac                 1
# Alaska Hare, Arctic Hare, Tundra Hare        1
# Name: animal_name, Length: 35825, dtype: int64

# %%
clean_species_df['national_park'].unique()
# Out:
# array(['Acadia National Park', 'Arches National Park',
#        'Badlands National Park', 'Big Bend National Park',
#        'Biscayne National Park',
#        'Black Canyon of the Gunnison National Park',
#        'Bryce Canyon National Park', 'Canyonlands National Park',
#        'Capitol Reef National Park', 'Carlsbad Caverns National Park',
#        'Channel Islands National Park', 'Congaree National Park',
#        'Crater Lake National Park', 'Cuyahoga Valley National Park',
#        'Death Valley National Park', 'Denali National Park and Preserve',
#        'Dry Tortugas National Park', 'Everglades National Park',
#        'Gates Of The Arctic National Park and Preserve',
#        'Glacier Bay National Park and Preserve', 'Glacier National Park',
#        'Grand Canyon National Park', 'Grand Teton National Park',
#        'Great Basin National Park',
#        'Great Sand Dunes National Park and Preserve',
#        'Great Smoky Mountains National Park',
#        'Guadalupe Mountains National Park', 'Haleakala National Park',
#        'Hawaii Volcanoes National Park', 'Hot Springs National Park',
#        'Isle Royale National Park', 'Joshua Tree National Park',
#        'Katmai National Park and Preserve', 'Kenai Fjords National Park',
#        'Kobuk Valley National Park',
#        'Lake Clark National Park and Preserve',
#        'Lassen Volcanic National Park', 'Mammoth Cave National Park',
#        'Mesa Verde National Park', 'Mount Rainier National Park',
#        'North Cascades National Park', 'Olympic National Park',
#        'Petrified Forest National Park', 'Pinnacles National Park',
#        'Redwood National Park', 'Rocky Mountain National Park',
#        'Saguaro National Park', 'Sequoia and Kings Canyon National Parks',
#        'Shenandoah National Park', 'Theodore Roosevelt National Park',
#        'Voyageurs National Park', 'Wind Cave National Park',
#        'Wrangell - St Elias National Park and Preserve',
#        'Yellowstone National Park', 'Yosemite National Park',
#        'Zion National Park'], dtype=object)

# %%
clean_species_df.to_csv("../Outputs/species_stats.csv", index=False)

# %%
park_visitation_df['YearRaw'].unique()
# Out:
# array(['1904', '1941', '1961', '1935', '1982', '1919', '1969', '1967',
#        '1944', '1989', '1988', '1993', '1955', '1976', '1980', '1934',
#        '1951', '1925', '1948', '1931', '1940', '1971', '1979', '2011',
#        '2004', '1968', '1984', '1987', '1985', '1973', '1936', '1992',
#        '1920', '1991', '1957', '1964', '1937', '1966', '1974', '1995',
#        '1962', '1929', '1997', '1950', '1942', '1956', '1972', '1970',
#        '2000', '1933', '1924', '1921', '2010', '1978', '1975', '1906',
#        '1996', '2003', '2006', '1947', '2002', '1908', '1965', '1939',
#        '1960', '1938', '1963', '2001', '1954', '1958', '2013', '1981',
#        '1952', '1923', '1983', '2016', '1998', '2007', '2015', '1915',
#        '1911', '1917', 'Total', '1930', '1932', '1922', '1926', '1986',
#        '1990', '2014', '1994', '2012', '1977', '2009', '2008', '2005',
#        '1999', '1959', '1946', '1945', '1953', '1943', '1949', '1928',
#        '1927', '1918', '1916', '1914', '1913', '1912', '1910', '1909',
#        '1905', '1907'], dtype=object)

# %%
new_park_visitation = park_visitation_df.loc[(park_visitation_df['YearRaw'] == '2016') & (park_visitation_df['Unit Type'] == 'National Park')]
new_park_visitation.head()
# Out:
#     Created By  Measure Selector                  Year   Date Edit  \
# 768     Legacy                 1  1/1/2016 12:00:00 AM   4/22/2015
# 771     Legacy                 1  1/1/2016 12:00:00 AM   4/22/2015
# 773     Legacy                 1  1/1/2016 12:00:00 AM  12/18/2013
# 776     Legacy                 1  1/1/2016 12:00:00 AM  12/18/2013
# 790     Legacy                 1  1/1/2016 12:00:00 AM  12/18/2013
#
#                                              ScrapeURL  \
# 768  https://irma.nps.gov/Stats/SSRSReports/Park%20...
# 771  https://irma.nps.gov/Stats/SSRSReports/Park%20...
# 773  https://irma.nps.gov/Stats/SSRSReports/Park%20...
# 776  https://irma.nps.gov/Stats/SSRSReports/Park%20...
# 790  https://irma.nps.gov/Stats/SSRSReports/Park%20...
#
#                                              GIS Notes  Gnis Id      Geometry  \
# 768  LEGACY: contact allen_mccoy@nps.gov for additi...  1163670       POLYGON
# 771  LEGACY: contact allen_mccoy@nps.gov for additi...  1530459  MULTIPOLYGON
# 773  LEGACY: NPS Inventory and Monitoring Program D...   578853  MULTIPOLYGON
# 776  LEGACY: NPS Inventory and Monitoring Program D...  1377082       POLYGON
# 790  LEGACY: NPS Inventory and Monitoring Program D...   293666       POLYGON
#
#     Metadata  Number of Records     Parkname Region State Unit Code  \
# 768      NaN                  1  Crater Lake     PW    OR      CRLA
# 771      NaN                  1      Olympic     PW    WA      OLYM
# 773      NaN                  1          NaN     NE    ME      ACAD
# 776      NaN                  1          NaN     IM    TX      BIBE
# 790      NaN                  1          NaN     SE    FL      EVER
#
#                      Unit Name      Unit Type   Visitors YearRaw
# 768  Crater Lake National Park  National Park   756344.0    2016
# 771      Olympic National Park  National Park  3390221.0    2016
# 773       Acadia National Park  National Park  3303393.0    2016
# 776     Big Bend National Park  National Park   388290.0    2016
# 790   Everglades National Park  National Park   930907.0    2016

# %%
new_park_visitation.describe()
# Out:
#        Measure Selector  Number of Records      Visitors
# count              61.0               61.0  6.100000e+01
# mean                1.0                1.0  1.375743e+06
# std                 0.0                0.0  1.904489e+06
# min                 1.0                1.0  1.004700e+04
# 25%                 1.0                1.0  3.465340e+05
# 50%                 1.0                1.0  6.074790e+05
# 75%                 1.0                1.0  1.544300e+06
# max                 1.0                1.0  1.131279e+07

# %%
park_visits_df = new_park_visitation[['Unit Name', 'Visitors']].copy()
park_visits_df.head()
# Out:
#                      Unit Name   Visitors
# 768  Crater Lake National Park   756344.0
# 771      Olympic National Park  3390221.0
# 773       Acadia National Park  3303393.0
# 776     Big Bend National Park   388290.0
# 790   Everglades National Park   930907.0

# %%
# clean_visits_df = park_visits_df.replace({
#     'AL': 'Alabama',
#     'AK': 'Alaska',
#     'AZ': 'Arizona',
#     'AR': 'Arkansas',
#     'CA': 'California',
#     'CO': 'Colorado',
#     'CT': 'Connecticut',
#     'DE': 'Delaware',
#     'FL': 'Florida',
#     'GA': 'Georgia',
#     'HI': 'Hawaii',
#     'ID': 'Idaho',
#     'IL': 'Illinois',
#     'IN': 'Indiana',
#     'IA': 'Iowa',
#     'KS': 'Kansas',
#     'KY': 'Kentucky',
#     'LA': 'Louisiana',
#     'ME': 'Maine',
#     'MD': 'Maryland',
#     'MA': 'Massachusetts',
#     'MI': 'Michigan',
#     'MN': 'Minnesota',
#     'MS': 'Mississippi',
#     'MO': 'Missouri',
#     'MT': 'Montana',
#     'NE': 'Nebraska',
#     'NV': 'Nevada',
#     'NH': 'New Hampshire',
#     'NJ': 'New Jersey',
#     'NM': 'New Mexico',
#     'NY': 'New York',
#     'NC': 'North Carolina',
#     'ND': 'North Dakota',
#     'OH': 'Ohio',
#     'OK': 'Oklahoma',
#     'OR': 'Oregon',
#     'PA': 'Pennsylvania',
#     'RI': 'Rhode Island',
#     'SC': 'South Carolina',
#     'SD': 'South Dakota',
#     'TN': 'Tennessee',
#     'TX': 'Texas',
#     'UT': 'Utah',
#     'VT': 'Vermont',
#     'VA': 'Virginia',
#     'WA': 'Washington',
#     'WV': 'West Virginia',
#     'WI': 'Wisconsin',
#     'WY': 'Wyoming'
# })
# clean_visits_df.head()

# %%
clean_visits_df = park_visits_df.rename(columns = {"Unit Name": "national_park", "Visitors": "visitors"})
clean_visits_df = clean_visits_df.sort_values('national_park')
clean_visits_df
# Out:
#                                         national_park   visitors
# 773                              Acadia National Park  3303393.0
# 848                              Arches National Park  1585718.0
# 1065                           Badlands National Park   996263.0
# 776                            Big Bend National Park   388290.0
# 942                            Biscayne National Park   514709.0
# ...                                               ...        ...
# 824   Wolf Trap National Park for the Performing Arts   437513.0
# 1127                 Wrangell-St. Elias National Park    79047.0
# 878                         Yellowstone National Park  4257177.0
# 1087                           Yosemite National Park  5028868.0
# 981                                Zion National Park  4295127.0
#
# [61 rows x 2 columns]

# %%
clean_visits_df.count()
# Out:
# national_park    61
# visitors         61
# dtype: int64

# %%
clean_visits_df['national_park'].unique()
# Out:
# array(['Acadia National Park', 'Arches National Park',
#        'Badlands National Park', 'Big Bend National Park',
#        'Biscayne National Park',
#        'Black Canyon of the Gunnison National Park',
#        'Bryce Canyon National Park', 'Canyonlands National Park',
#        'Capitol Reef National Park', 'Carlsbad Caverns National Park',
#        'Channel Islands National Park', 'Congaree National Park',
#        'Crater Lake National Park', 'Cuyahoga Valley National Park',
#        'Death Valley National Park', 'Denali National Park',
#        'Denali National Preserve', 'Dry Tortugas National Park',
#        'Everglades National Park', 'Gates of the Arctic National Park',
#        'Glacier Bay National Park', 'Glacier National Park',
#        'Grand Canyon National Park', 'Grand Teton National Park',
#        'Great Basin National Park', 'Great Sand Dunes National Park',
#        'Great Smoky Mountains National Park',
#        'Guadalupe Mountains National Park', 'Haleakala National Park',
#        "Hawai'i Volcanoes National Park", 'Hot Springs National Park',
#        'Isle Royale National Park', 'Joshua Tree National Park',
#        'Katmai National Park', 'Kenai Fjords National Park',
#        'Kings Canyon National Park', 'Kobuk Valley National Park',
#        'Lake Clark National Park', 'Lassen Volcanic National Park',
#        'Mammoth Cave National Park', 'Mesa Verde National Park',
#        'Mount Rainier National Park', 'National Park of American Samoa',
#        'North Cascades National Park', 'Olympic National Park',
#        'Petrified Forest National Park', 'Pinnacles National Park',
#        'Redwood National Park', 'Rocky Mountain National Park',
#        'Saguaro National Park', 'Sequoia National Park',
#        'Shenandoah National Park', 'Theodore Roosevelt National Park',
#        'Virgin Islands National Park', 'Voyageurs National Park',
#        'Wind Cave National Park',
#        'Wolf Trap National Park for the Performing Arts',
#        'Wrangell-St. Elias National Park', 'Yellowstone National Park',
#        'Yosemite National Park', 'Zion National Park'], dtype=object)

# %%
visits_replace = {
    "Hawai'i": "Hawaii",
    "Wrangell-St.": "Wrangell - St",
}
clean_visits_df = clean_visits_df.replace(visits_replace, regex=True)
clean_visits_df['national_park'] = clean_visits_df['national_park'].str.strip()
clean_visits_df['national_park'].unique()
# Out:
# array(['Acadia National Park', 'Arches National Park',
#        'Badlands National Park', 'Big Bend National Park',
#        'Biscayne National Park',
#        'Black Canyon of the Gunnison National Park',
#        'Bryce Canyon National Park', 'Canyonlands National Park',
#        'Capitol Reef National Park', 'Carlsbad Caverns National Park',
#        'Channel Islands National Park', 'Congaree National Park',
#        'Crater Lake National Park', 'Cuyahoga Valley National Park',
#        'Death Valley National Park', 'Denali National Park',
#        'Denali National Preserve', 'Dry Tortugas National Park',
#        'Everglades National Park', 'Gates of the Arctic National Park',
#        'Glacier Bay National Park', 'Glacier National Park',
#        'Grand Canyon National Park', 'Grand Teton National Park',
#        'Great Basin National Park', 'Great Sand Dunes National Park',
#        'Great Smoky Mountains National Park',
#        'Guadalupe Mountains National Park', 'Haleakala National Park',
#        'Hawaii Volcanoes National Park', 'Hot Springs National Park',
#        'Isle Royale National Park', 'Joshua Tree National Park',
#        'Katmai National Park', 'Kenai Fjords National Park',
#        'Kings Canyon National Park', 'Kobuk Valley National Park',
#        'Lake Clark National Park', 'Lassen Volcanic National Park',
#        'Mammoth Cave National Park', 'Mesa Verde National Park',
#        'Mount Rainier National Park', 'National Park of American Samoa',
#        'North Cascades National Park', 'Olympic National Park',
#        'Petrified Forest National Park', 'Pinnacles National Park',
#        'Redwood National Park', 'Rocky Mountain National Park',
#        'Saguaro National Park', 'Sequoia National Park',
#        'Shenandoah National Park', 'Theodore Roosevelt National Park',
#        'Virgin Islands National Park', 'Voyageurs National Park',
#        'Wind Cave National Park',
#        'Wolf Trap National Park for the Performing Arts',
#        'Wrangell - St Elias National Park', 'Yellowstone National Park',
#        'Yosemite National Park', 'Zion National Park'], dtype=object)

# %%
csv_path = "../Resources/nps_df.csv"
nps_df = pd.read_csv(csv_path)
nps_df.head()
# Out:
#   park_code           national_park         state   acres  latitude  longitude
# 0      ACAD    Acadia National Park         Maine   47390     44.35     -68.21
# 1      ARCH    Arches National Park          Utah   76519     38.68    -109.57
# 2      BADL  Badlands National Park  South Dakota  242756     43.75    -102.50
# 3      BIBE  Big Bend National Park         Texas  801163     29.25    -103.25
# 4      BISC  Biscayne National Park       Florida  172924     25.65     -80.08

# %%
nps_replace = {
    "and Preserve": "",
    "The ": "the ",
    "Of ": "of "
}
clean_nps_df = nps_df.replace(nps_replace, regex=True)
clean_nps_df['national_park'] = clean_nps_df['national_park'].str.strip()
clean_nps_df['national_park'].unique()
# Out:
# array(['Acadia National Park', 'Arches National Park',
#        'Badlands National Park', 'Big Bend National Park',
#        'Biscayne National Park',
#        'Black Canyon of the Gunnison National Park',
#        'Bryce Canyon National Park', 'Canyonlands National Park',
#        'Capitol Reef National Park', 'Carlsbad Caverns National Park',
#        'Channel Islands National Park', 'Congaree National Park',
#        'Crater Lake National Park', 'Cuyahoga Valley National Park',
#        'Denali National Park', 'Death Valley National Park',
#        'Dry Tortugas National Park', 'Everglades National Park',
#        'Gates of the Arctic National Park', 'Glacier National Park',
#        'Glacier Bay National Park', 'Great Basin National Park',
#        'Grand Canyon National Park', 'Great Sand Dunes National Park',
#        'Great Smoky Mountains National Park', 'Grand Teton National Park',
#        'Guadalupe Mountains National Park', 'Haleakala National Park',
#        'Hawaii Volcanoes National Park', 'Hot Springs National Park',
#        'Isle Royale National Park', 'Joshua Tree National Park',
#        'Katmai National Park', 'Kenai Fjords National Park',
#        'Kobuk Valley National Park', 'Lake Clark National Park',
#        'Lassen Volcanic National Park', 'Mammoth Cave National Park',
#        'Mesa Verde National Park', 'Mount Rainier National Park',
#        'North Cascades National Park', 'Olympic National Park',
#        'Petrified Forest National Park', 'Pinnacles National Park',
#        'Redwood National Park', 'Rocky Mountain National Park',
#        'Saguaro National Park', 'Sequoia and Kings Canyon National Parks',
#        'Shenandoah National Park', 'Theodore Roosevelt National Park',
#        'Voyageurs National Park', 'Wind Cave National Park',
#        'Wrangell - St Elias National Park', 'Yellowstone National Park',
#        'Yosemite National Park', 'Zion National Park'], dtype=object)

# %%
merge_nps_df = pd.DataFrame.merge(clean_nps_df, clean_visits_df, how="left")
merge_nps_df.head()
# Out:
#   park_code           national_park         state   acres  latitude  \
# 0      ACAD    Acadia National Park         Maine   47390     44.35
# 1      ARCH    Arches National Park          Utah   76519     38.68
# 2      BADL  Badlands National Park  South Dakota  242756     43.75
# 3      BIBE  Big Bend National Park         Texas  801163     29.25
# 4      BISC  Biscayne National Park       Florida  172924     25.65
#
#    longitude   visitors
# 0     -68.21  3303393.0
# 1    -109.57  1585718.0
# 2    -102.50   996263.0
# 3    -103.25   388290.0
# 4     -80.08   514709.0

# %%
merge_nps_df['national_park'].value_counts()
# Out:
# Great Basin National Park                     1
# Big Bend National Park                        1
# Crater Lake National Park                     1
# Congaree National Park                        1
# Yellowstone National Park                     1
# Lassen Volcanic National Park                 1
# Great Smoky Mountains National Park           1
# Everglades National Park                      1
# Canyonlands National Park                     1
# Zion National Park                            1
# Saguaro National Park                         1
# Olympic National Park                         1
# Guadalupe Mountains National Park             1
# Kobuk Valley National Park                    1
# Mammoth Cave National Park                    1
# Shenandoah National Park                      1
# Gates of the Arctic National Park             1
# Bryce Canyon National Park                    1
# Grand Canyon National Park                    1
# Kenai Fjords National Park                    1
# Badlands National Park                        1
# Pinnacles National Park                       1
# Grand Teton National Park                     1
# Biscayne National Park                        1
# Denali National Park                          1
# Glacier National Park                         1
# Arches National Park                          1
# Glacier Bay National Park                     1
# Katmai National Park                          1
# Lake Clark National Park                      1
# Wind Cave National Park                       1
# Capitol Reef National Park                    1
# Cuyahoga Valley National Park                 1
# Dry Tortugas National Park                    1
# North Cascades National Park                  1
# Voyageurs National Park                       1
# Redwood National Park                         1
# Carlsbad Caverns National Park                1
# Isle Royale National Park                     1
# Petrified Forest National Park                1
# Mount Rainier National Park                   1
# Sequoia and Kings Canyon National Parks       1
# Rocky Mountain National Park                  1
# Death Valley National Park                    1
# Wrangell - St Elias National Park             1
# Joshua Tree National Park                     1
# Great Sand Dunes National Park                1
# Hawaii Volcanoes National Park                1
# Channel Islands National Park                 1
# Mesa Verde National Park                      1
# Hot Springs National Park                     1
# Haleakala National Park                       1
# Black Canyon of the Gunnison National Park    1
# Theodore Roosevelt National Park              1
# Acadia National Park                          1
# Yosemite National Park                        1
# Name: national_park, dtype: int64

# %%
merge_nps_df.count()
# Out:
# park_code        56
# national_park    56
# state            56
# acres            56
# latitude         56
# longitude        56
# visitors         55
# dtype: int64

# %%
merge_nps_df.tail(10)
# Out:
#    park_code                            national_park         state    acres  \
# 46      SAGU                    Saguaro National Park       Arizona    91440
# 47      SEKI  Sequoia and Kings Canyon National Parks    California   865952
# 48      SHEN                 Shenandoah National Park      Virginia   199045
# 49      THRO         Theodore Roosevelt National Park  North Dakota    70447
# 50      VOYA                  Voyageurs National Park     Minnesota   218200
# 51      WICA                  Wind Cave National Park  South Dakota    28295
# 52      WRST        Wrangell - St Elias National Park        Alaska  8323148
# 53      YELL                Yellowstone National Park    WY, MT, ID  2219791
# 54      YOSE                   Yosemite National Park    California   761266
# 55      ZION                       Zion National Park          Utah   146598
#
#     latitude  longitude   visitors
# 46     32.25    -110.50   820426.0
# 47     36.43    -118.68        NaN
# 48     38.53     -78.35  1437341.0
# 49     46.97    -103.45   753880.0
# 50     48.50     -92.88   241912.0
# 51     43.57    -103.48   617377.0
# 52     61.00    -142.00    79047.0
# 53     44.60    -110.50  4257177.0
# 54     37.83    -119.50  5028868.0
# 55     37.30    -113.05  4295127.0

# %%
merge_nps_df.to_csv("../Outputs/national_parks.csv", index=False)

# %%
trails_path = "../Outputs/trails.csv"
trails_df = pd.read_csv(trails_path)
trails_df.sort_values('national_park')
# Out:
#       trail_id                                         trail_name  \
# 1430  10350967                                 Pretty Marsh Trail
# 1349  10009579                                  Valley Peak Trail
# 1350  10319881  Cannon Brook, Cadillac South Ridge and Ladder ...
# 1351  10239622             Carriage and Around Mountain Road Loop
# 1352  10356349               Bubbles Divide via Jordans Pond Path
#
#              national_park  state  trailhead_lat  trailhead_long
# 1430  Acadia National Park  Maine       44.33242       -68.40727
# 1349  Acadia National Park  Maine       44.29948       -68.31631
# 1350  Acadia National Park  Maine       44.35166       -68.20437
# 1351  Acadia National Park  Maine       44.31224       -68.28545
# 1352  Acadia National Park  Maine       44.32370       -68.24989

# %%
trails_df['national_park'].unique()
# Out:
# array(['Kenai Fjords National Park', 'Denali National Park',
#        'Glacier Bay National Park', 'Katmai National Park',
#        'Grand Canyon National Park', 'Saguaro National Park',
#        'Petrified Forest National Park', 'Hot Springs National Park',
#        'Yosemite National Park', 'Sequoia National Park',
#        'Joshua Tree National Park', 'Lassen Volcanic National Park',
#        'Kings Canyon National Park', 'Pinnacles National Park',
#        'Death Valley National Park', 'Redwood National Park',
#        'Channel Islands National Park', 'Rocky Mountain National Park',
#        'Great Sand Dunes National Park and Preserve',
#        'Mesa Verde National Park',
#        'Black Canyon of the Gunnison National Park',
#        'Everglades National Park', 'Fort Pickens National Park',
#        'Biscayne National Park', 'Dry Tortugas National Park',
#        'Clayton Co International Park, Jonesboro GA',
#        'Indiana Dunes National Park', 'Mammoth Cave National Park',
#        'Acadia National Park', 'Isle Royale National Park',
#        'Voyageurs National Park', 'Gateway Arch National Park',
#        'Glacier National Park', 'Yellowstone National Park',
#        'Great Basin National Park', 'Carlsbad Caverns National Park',
#        'Great Smoky Mountains National Park',
#        'Theodore Roosevelt National Park',
#        'Cuyahoga Valley National Park', 'Crater Lake National Park',
#        'Congaree National Park', 'Congaree National Park Wilderness',
#        'Badlands National Park', 'Wind Cave National Park',
#        'Guadalupe Mountains National Park', 'Big Bend National Park',
#        'Zion National Park', 'Arches National Park',
#        'Bryce Canyon National Park', 'Canyonlands National Park',
#        'Capitol Reef National Park', 'Shenandoah National Park',
#        'Fort Hunt National Park',
#        'Wolf Trap National Park for the Performing Arts',
#        'Mount Rainier National Park', 'Olympic National Park',
#        'North Cascades National Park', 'Grand Teton National Park',
#        'Hawaii Volcanoes National Park', 'Haleakala National Park'],
#       dtype=object)

# %%
trail_park_ids = pd.DataFrame.merge(trails_df, clean_nps_df, how="left", on="national_park").sort_values("national_park")
trail_park_ids.head()
# Out:
#       trail_id                                         trail_name  \
# 1430  10350967                                 Pretty Marsh Trail
# 1349  10009579                                  Valley Peak Trail
# 1350  10319881  Cannon Brook, Cadillac South Ridge and Ladder ...
# 1351  10239622             Carriage and Around Mountain Road Loop
# 1352  10356349               Bubbles Divide via Jordans Pond Path
#
#              national_park state_x  trailhead_lat  trailhead_long park_code  \
# 1430  Acadia National Park   Maine       44.33242       -68.40727      ACAD
# 1349  Acadia National Park   Maine       44.29948       -68.31631      ACAD
# 1350  Acadia National Park   Maine       44.35166       -68.20437      ACAD
# 1351  Acadia National Park   Maine       44.31224       -68.28545      ACAD
# 1352  Acadia National Park   Maine       44.32370       -68.24989      ACAD
#
#      state_y    acres  latitude  longitude
# 1430   Maine  47390.0     44.35     -68.21
# 1349   Maine  47390.0     44.35     -68.21
# 1350   Maine  47390.0     44.35     -68.21
# 1351   Maine  47390.0     44.35     -68.21
# 1352   Maine  47390.0     44.35     -68.21

# %%
trail_park_ids.count()
# Out:
# trail_id          3313
# trail_name        3313
# national_park     3313
# state_x           3313
# trailhead_lat     3313
# trailhead_long    3313
# park_code         3122
# state_y           3122
# acres             3122
# latitude          3122
# longitude         3122
# dtype: int64

# %%
trail_park_ids['national_park'].unique()
# Out:
# array(['Acadia National Park', 'Arches National Park',
#        'Badlands National Park', 'Big Bend National Park',
#        'Biscayne National Park',
#        'Black Canyon of the Gunnison National Park',
#        'Bryce Canyon National Park', 'Canyonlands National Park',
#        'Capitol Reef National Park', 'Carlsbad Caverns National Park',
#        'Channel Islands National Park',
#        'Clayton Co International Park, Jonesboro GA',
#        'Congaree National Park', 'Congaree National Park Wilderness',
#        'Crater Lake National Park', 'Cuyahoga Valley National Park',
#        'Death Valley National Park', 'Denali National Park',
#        'Dry Tortugas National Park', 'Everglades National Park',
#        'Fort Hunt National Park', 'Fort Pickens National Park',
#        'Gateway Arch National Park', 'Glacier Bay National Park',
#        'Glacier National Park', 'Grand Canyon National Park',
#        'Grand Teton National Park', 'Great Basin National Park',
#        'Great Sand Dunes National Park and Preserve',
#        'Great Smoky Mountains National Park',
#        'Guadalupe Mountains National Park', 'Haleakala National Park',
#        'Hawaii Volcanoes National Park', 'Hot Springs National Park',
#        'Indiana Dunes National Park', 'Isle Royale National Park',
#        'Joshua Tree National Park', 'Katmai National Park',
#        'Kenai Fjords National Park', 'Kings Canyon National Park',
#        'Lassen Volcanic National Park', 'Mammoth Cave National Park',
#        'Mesa Verde National Park', 'Mount Rainier National Park',
#        'North Cascades National Park', 'Olympic National Park',
#        'Petrified Forest National Park', 'Pinnacles National Park',
#        'Redwood National Park', 'Rocky Mountain National Park',
#        'Saguaro National Park', 'Sequoia National Park',
#        'Shenandoah National Park', 'Theodore Roosevelt National Park',
#        'Voyageurs National Park', 'Wind Cave National Park',
#        'Wolf Trap National Park for the Performing Arts',
#        'Yellowstone National Park', 'Yosemite National Park',
#        'Zion National Park'], dtype=object)

# %%
# nulls = trail_park_ids['park_code'].isnull()
# nulls
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3308    False
# 3309    False
# 3310    False
# 3311    False
# 3312    False
# Name: park_code, Length: 3313, dtype: bool

# %%
nans = trail_park_ids.loc[trail_park_ids['park_code'] == "NaN"]
nans
# Out:
# Empty DataFrame
# Columns: [trail_id, trail_name, national_park, state, trailhead_lat, trailhead_long, park_code, acres, latitude, longitude]
# Index: []

# %%
from sqlalchemy import create_engine

# %%
connection_string = "postgres:postgres@localhost:5432/NationalParks"
engine = create_engine(f'postgresql://{connection_string}')

# %%
engine.table_names()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2274         try:
# -> 2275             return fn()
#    2276         except dialect.dbapi.Error as e:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     362         if not self._use_threadlocal:
# --> 363             return _ConnectionFairy._checkout(self)
#     364
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     759         if not fairy:
# --> 760             fairy = _ConnectionRecord.checkout(pool)
#     761
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     491     def checkout(cls, pool):
# --> 492         rec = pool._do_get()
#     493         try:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     138                 with util.safe_reraise():
# --> 139                     self._dec_overflow()
#     140         else:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
# ---> 68                 compat.reraise(exc_type, exc_value, exc_tb)
#      69         else:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     152             raise value.with_traceback(tb)
# --> 153         raise value
#     154
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     135             try:
# --> 136                 return self._create_connection()
#     137             except:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     307
# --> 308         return _ConnectionRecord(self)
#     309
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     436         if connect:
# --> 437             self.__connect(first_connect_check=True)
#     438         self.finalize_callback = deque()
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     638             self.starttime = time.time()
# --> 639             connection = pool._invoke_creator(self)
#     640             pool.logger.debug("Created new connection %r", connection)
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     480     def connect(self, *cargs, **cparams):
# --> 481         return self.dbapi.connect(*cargs, **cparams)
#     482
#
# ~\Anaconda3\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#
# OperationalError: FATAL:  password authentication failed for user "postgres"
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-72-d72bc75a6b62> in <module>
# ----> 1 engine.table_names()
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in table_names(self, schema, connection)
#    2251         """
#    2252
# -> 2253         with self._optional_conn_ctx_manager(connection) as conn:
#    2254             if not schema:
#    2255                 schema = self.dialect.default_schema_name
#
# ~\Anaconda3\lib\contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _optional_conn_ctx_manager(self, connection)
#    2035     def _optional_conn_ctx_manager(self, connection=None):
#    2036         if connection is None:
# -> 2037             with self._contextual_connect() as conn:
#    2038                 yield conn
#    2039         else:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _contextual_connect(self, close_with_result, **kwargs)
#    2237         return self._connection_cls(
#    2238             self,
# -> 2239             self._wrap_pool_connect(self.pool.connect, None),
#    2240             close_with_result=close_with_result,
#    2241             **kwargs
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2277             if connection is None:
#    2278                 Connection._handle_dbapi_exception_noconnection(
# -> 2279                     e, dialect, self
#    2280                 )
#    2281             else:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1542             util.raise_from_cause(newraise, exc_info)
#    1543         elif should_wrap:
# -> 1544             util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1545         else:
#    1546             util.reraise(*exc_info)
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     396     exc_type, exc_value, exc_tb = exc_info
#     397     cause = exc_value if exc_value is not exception else None
# --> 398     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     399
#     400
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     150             value.__cause__ = cause
#     151         if value.__traceback__ is not tb:
# --> 152             raise value.with_traceback(tb)
#     153         raise value
#     154
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2273         dialect = self.dialect
#    2274         try:
# -> 2275             return fn()
#    2276         except dialect.dbapi.Error as e:
#    2277             if connection is None:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     361         """
#     362         if not self._use_threadlocal:
# --> 363             return _ConnectionFairy._checkout(self)
#     364
#     365         try:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     758     def _checkout(cls, pool, threadconns=None, fairy=None):
#     759         if not fairy:
# --> 760             fairy = _ConnectionRecord.checkout(pool)
#     761
#     762             fairy._pool = pool
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     490     @classmethod
#     491     def checkout(cls, pool):
# --> 492         rec = pool._do_get()
#     493         try:
#     494             dbapi_connection = rec.get_connection()
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     137             except:
#     138                 with util.safe_reraise():
# --> 139                     self._dec_overflow()
#     140         else:
#     141             return self._do_get()
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      66             self._exc_info = None  # remove potential circular references
#      67             if not self.warn_only:
# ---> 68                 compat.reraise(exc_type, exc_value, exc_tb)
#      69         else:
#      70             if not compat.py3k and self._exc_info and self._exc_info[1]:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     151         if value.__traceback__ is not tb:
#     152             raise value.with_traceback(tb)
# --> 153         raise value
#     154
#     155     def u(s):
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     134         if self._inc_overflow():
#     135             try:
# --> 136                 return self._create_connection()
#     137             except:
#     138                 with util.safe_reraise():
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     306         """Called by subclasses to create a new ConnectionRecord."""
#     307
# --> 308         return _ConnectionRecord(self)
#     309
#     310     def _invalidate(self, connection, exception=None, _checkin=True):
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     435         self.__pool = pool
#     436         if connect:
# --> 437             self.__connect(first_connect_check=True)
#     438         self.finalize_callback = deque()
#     439
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     637         try:
#     638             self.starttime = time.time()
# --> 639             connection = pool._invoke_creator(self)
#     640             pool.logger.debug("Created new connection %r", connection)
#     641             self.connection = connection
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     112                         if connection is not None:
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#     116             creator = pop_kwarg("creator", connect)
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     479
#     480     def connect(self, *cargs, **cparams):
# --> 481         return self.dbapi.connect(*cargs, **cparams)
#     482
#     483     def create_connect_args(self, url):
#
# ~\Anaconda3\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     125
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#     129         conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) FATAL:  password authentication failed for user "postgres"
#
# (Background on this error at: http://sqlalche.me/e/e3q8)
