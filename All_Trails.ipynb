# %%
import pandas as pd

# %%
csv_path = "Resources/AllTrails_data_nationalpark.csv"
all_trails_df = pd.read_csv(csv_path)
all_trails_df.head()
# Out:
#    trail_id                        name                   area_name  \
# 0  10020048     Harding Ice Field Trail  Kenai Fjords National Park
# 1  10236086  Mount Healy Overlook Trail        Denali National Park
# 2  10267857          Exit Glacier Trail  Kenai Fjords National Park
# 3  10236076        Horseshoe Lake Trail        Denali National Park
# 4  10236082          Triple Lakes Trail        Denali National Park
#
#               city_name state_name   country_name  \
# 0                Seward     Alaska  United States
# 1  Denali National Park     Alaska  United States
# 2                Seward     Alaska  United States
# 3  Denali National Park     Alaska  United States
# 4  Denali National Park     Alaska  United States
#
#                                 _geoloc  popularity     length  \
# 0  {'lat': 60.18852, 'lng': -149.63156}     24.8931  15610.598
# 1  {'lat': 63.73049, 'lng': -148.91968}     18.0311   6920.162
# 2    {'lat': 60.18879, 'lng': -149.631}     17.7821   2896.812
# 3    {'lat': 63.73661, 'lng': -148.915}     16.2674   3379.614
# 4  {'lat': 63.73319, 'lng': -148.89682}     12.5935  29772.790
#
#    elevation_gain  difficulty_rating    route_type  visitor_usage  avg_rating  \
# 0       1161.8976                  5  out and back            3.0         5.0
# 1        507.7968                  3  out and back            1.0         4.5
# 2         81.9912                  1  out and back            3.0         4.5
# 3        119.7864                  1          loop            2.0         4.5
# 4       1124.7120                  5  out and back            1.0         4.5
#
#    num_reviews                                           features  \
# 0          423  ['dogs-no', 'forest', 'river', 'views', 'water...
# 1          260  ['dogs-no', 'forest', 'views', 'wild-flowers',...
# 2          224  ['dogs-no', 'partially-paved', 'views', 'wildl...
# 3          237  ['dogs-no', 'forest', 'lake', 'kids', 'views',...
# 4          110  ['dogs-no', 'lake', 'views', 'wild-flowers', '...
#
#                                           activities units
# 0  ['birding', 'camping', 'hiking', 'nature-trips...     i
# 1  ['birding', 'camping', 'hiking', 'nature-trips...     i
# 2                              ['hiking', 'walking']     i
# 3  ['birding', 'hiking', 'nature-trips', 'trail-r...     i
# 4  ['birding', 'fishing', 'hiking', 'nature-trips...     i

# %%
visitor_usage = all_trails_df['visitor_usage'].describe()
print(visitor_usage)
# Out:
# count    3060.000000
# mean        1.877124
# std         0.693641
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         2.000000
# max         4.000000
# Name: visitor_usage, dtype: float64

# %%
all_trails_df['name'].value_counts()
# Out:
# Black Canyon Trail                  3
# White Wolf to Aspen Valley Trail    2
# Shafer Trail                        2
# Grand View Point Trail              2
# Furnace Mountain Trail              2
#                                    ..
# Apgar Bike Trail                    1
# Paradise Creek Trail                1
# Lillian Ridge Way Trail             1
# Teton Village Tram Ride             1
# Chimney Tops Trail                  1
# Name: name, Length: 3288, dtype: int64

# %%
country = all_trails_df['country_name'].value_counts()
state = all_trails_df['state_name'].value_counts()
print(country)
print(state)
# Out:
# United States    3264
# Hawaii             49
# Name: country_name, dtype: int64
# California        707
# Washington        320
# Wyoming           311
# Utah              292
# Colorado          262
# Virginia          191
# Maine             179
# Tennessee         175
# Arizona           174
# Montana           151
# North Carolina    118
# Texas              94
# Ohio               50
# Hawaii             35
# Florida            31
# Alaska             29
# Kentucky           28
# Nevada             25
# North Dakota       23
# Oregon             22
# South Dakota       20
# Indiana            16
# Arkansas           16
# Maui               14
# New Mexico          8
# South Carolina      8
# Minnesota           7
# Michigan            4
# Missouri            2
# Georgia             1
# Name: state_name, dtype: int64

# %%
area_unique = all_trails_df['area_name'].unique()
print(len(area_unique))
area_unique
# Out:
# 60
# array(['Kenai Fjords National Park', 'Denali National Park',
#        'Glacier Bay National Park', 'Katmai National Park',
#        'Grand Canyon National Park', 'Saguaro National Park',
#        'Petrified Forest National Park', 'Hot Springs National Park',
#        'Yosemite National Park', 'Sequoia National Park',
#        'Joshua Tree National Park', 'Lassen Volcanic National Park',
#        'Kings Canyon National Park', 'Pinnacles National Park',
#        'Death Valley National Park', 'Redwood National Park',
#        'Channel Islands National Park', 'Rocky Mountain National Park',
#        'Great Sand Dunes National Park and Preserve',
#        'Mesa Verde National Park',
#        'Black Canyon of the Gunnison National Park',
#        'Everglades National Park', 'Fort Pickens National Park',
#        'Biscayne National Park', 'Dry Tortugas National Park',
#        'Clayton Co International Park, Jonesboro GA',
#        'Indiana Dunes National Park', 'Mammoth Cave National Park',
#        'Acadia National Park', 'Isle Royale National Park',
#        'Voyageurs National Park', 'Gateway Arch National Park',
#        'Glacier National Park', 'Yellowstone National Park',
#        'Great Basin National Park', 'Carlsbad Caverns National Park',
#        'Great Smoky Mountains National Park',
#        'Theodore Roosevelt National Park',
#        'Cuyahoga Valley National Park', 'Crater Lake National Park',
#        'Congaree National Park', 'Congaree National Park Wilderness',
#        'Badlands National Park', 'Wind Cave National Park',
#        'Guadalupe Mountains National Park', 'Big Bend National Park',
#        'Zion National Park', 'Arches National Park',
#        'Bryce Canyon National Park', 'Canyonlands National Park',
#        'Capitol Reef National Park', 'Shenandoah National Park',
#        'Fort Hunt National Park',
#        'Wolf Trap National Park for the Performing Arts',
#        'Mount Rainier National Park', 'Olympic National Park',
#        'North Cascades National Park', 'Grand Teton National Park',
#        'Hawaii Volcanoes National Park', 'Haleakala National Park'],
#       dtype=object)

# %%
unique_trails = all_trails_df['area_name'].unique()
len(unique_trails)
# Out:
# 60

# %%
features = all_trails_df['features'].value_counts()
print(features)
# Out:
# ['dogs-no', 'forest', 'views', 'wild-flowers', 'wildlife']                                           175
# ['dogs-no', 'views', 'wild-flowers', 'wildlife']                                                     121
# ['dogs-no', 'views']                                                                                 114
# ['dogs-no', 'forest', 'lake', 'views', 'wild-flowers', 'wildlife']                                   103
# ['dogs-no', 'forest', 'river', 'views', 'wild-flowers', 'wildlife']                                   78
#                                                                                                     ...
# ['dogs-no', 'kids', 'wild-flowers', 'wildlife']                                                        1
# ['dogs-leash', 'forest', 'lake', 'views', 'wild-flowers']                                              1
# ['beach', 'dogs-leash', 'forest', 'kids', 'partially-paved', 'views', 'wild-flowers', 'wildlife']      1
# ['forest', 'waterfall', 'wild-flowers']                                                                1
# ['beach', 'dogs-no', 'lake', 'kids', 'views', 'wildlife']                                              1
# Name: features, Length: 744, dtype: int64

# %%
activities = all_trails_df['activities'].value_counts()
print(activities)
# Out:
# ['birding', 'hiking', 'nature-trips', 'walking']                                                                            450
# ['birding', 'hiking', 'nature-trips', 'trail-running', 'walking']                                                           249
# ['birding', 'hiking', 'nature-trips']                                                                                       189
# ['hiking']                                                                                                                  156
# ['hiking', 'nature-trips', 'walking']                                                                                       127
#                                                                                                                            ...
# ['backpacking', 'birding', 'camping', 'fishing', 'hiking', 'nature-trips', 'walking', 'horseback-riding', 'fly-fishing']      1
# ['backpacking', 'camping', 'fishing', 'hiking', 'nature-trips', 'rock-climbing']                                              1
# ['birding', 'fishing', 'hiking', 'nature-trips', 'paddle-sports', 'fly-fishing', 'canoeing']                                  1
# ['hiking', 'mountain-biking', 'snowshoeing']                                                                                  1
# ['backpacking', 'birding', 'camping', 'fishing', 'hiking', 'nature-trips', 'walking', 'fly-fishing']                          1
# Name: activities, Length: 526, dtype: int64

# %%
all_trails_df.head()
# Out:
#    trail_id                        name                   area_name  \
# 0  10020048     Harding Ice Field Trail  Kenai Fjords National Park
# 1  10236086  Mount Healy Overlook Trail        Denali National Park
# 2  10267857          Exit Glacier Trail  Kenai Fjords National Park
# 3  10236076        Horseshoe Lake Trail        Denali National Park
# 4  10236082          Triple Lakes Trail        Denali National Park
#
#               city_name state_name   country_name  \
# 0                Seward     Alaska  United States
# 1  Denali National Park     Alaska  United States
# 2                Seward     Alaska  United States
# 3  Denali National Park     Alaska  United States
# 4  Denali National Park     Alaska  United States
#
#                                 _geoloc  popularity     length  \
# 0  {'lat': 60.18852, 'lng': -149.63156}     24.8931  15610.598
# 1  {'lat': 63.73049, 'lng': -148.91968}     18.0311   6920.162
# 2    {'lat': 60.18879, 'lng': -149.631}     17.7821   2896.812
# 3    {'lat': 63.73661, 'lng': -148.915}     16.2674   3379.614
# 4  {'lat': 63.73319, 'lng': -148.89682}     12.5935  29772.790
#
#    elevation_gain  difficulty_rating    route_type  visitor_usage  avg_rating  \
# 0       1161.8976                  5  out and back            3.0         5.0
# 1        507.7968                  3  out and back            1.0         4.5
# 2         81.9912                  1  out and back            3.0         4.5
# 3        119.7864                  1          loop            2.0         4.5
# 4       1124.7120                  5  out and back            1.0         4.5
#
#    num_reviews                                           features  \
# 0          423  ['dogs-no', 'forest', 'river', 'views', 'water...
# 1          260  ['dogs-no', 'forest', 'views', 'wild-flowers',...
# 2          224  ['dogs-no', 'partially-paved', 'views', 'wildl...
# 3          237  ['dogs-no', 'forest', 'lake', 'kids', 'views',...
# 4          110  ['dogs-no', 'lake', 'views', 'wild-flowers', '...
#
#                                           activities units
# 0  ['birding', 'camping', 'hiking', 'nature-trips...     i
# 1  ['birding', 'camping', 'hiking', 'nature-trips...     i
# 2                              ['hiking', 'walking']     i
# 3  ['birding', 'hiking', 'nature-trips', 'trail-r...     i
# 4  ['birding', 'fishing', 'hiking', 'nature-trips...     i

# %%
clean_all_trails = all_trails_df.drop(columns=['city_name', 'country_name', 'units', 'visitor_usage', 'features', 'activities'])
clean_all_trails.head()
# Out:
#    trail_id                        name                   area_name  \
# 0  10020048     Harding Ice Field Trail  Kenai Fjords National Park
# 1  10236086  Mount Healy Overlook Trail        Denali National Park
# 2  10267857          Exit Glacier Trail  Kenai Fjords National Park
# 3  10236076        Horseshoe Lake Trail        Denali National Park
# 4  10236082          Triple Lakes Trail        Denali National Park
#
#   state_name                               _geoloc  popularity     length  \
# 0     Alaska  {'lat': 60.18852, 'lng': -149.63156}     24.8931  15610.598
# 1     Alaska  {'lat': 63.73049, 'lng': -148.91968}     18.0311   6920.162
# 2     Alaska    {'lat': 60.18879, 'lng': -149.631}     17.7821   2896.812
# 3     Alaska    {'lat': 63.73661, 'lng': -148.915}     16.2674   3379.614
# 4     Alaska  {'lat': 63.73319, 'lng': -148.89682}     12.5935  29772.790
#
#    elevation_gain  difficulty_rating    route_type  avg_rating  num_reviews
# 0       1161.8976                  5  out and back         5.0          423
# 1        507.7968                  3  out and back         4.5          260
# 2         81.9912                  1  out and back         4.5          224
# 3        119.7864                  1          loop         4.5          237
# 4       1124.7120                  5  out and back         4.5          110

# %%
print(clean_all_trails[clean_all_trails['area_name']=="Clayton Co International Park, Jonesboro GA"])
# Out:
#       trail_id                                     name  \
# 1219  10259207  Clayton County International Park Trail
#
#                                         area_name state_name  \
# 1219  Clayton Co International Park, Jonesboro GA    Georgia
#
#                                  _geoloc  popularity    length  \
# 1219  {'lat': 33.5312, 'lng': -84.31568}      4.7291  2574.944
#
#       elevation_gain  difficulty_rating route_type  avg_rating  num_reviews
# 1219         36.8808                  3       loop         4.0           26

# %%
clean_all_trails.drop([1219], inplace = True)
clean_all_trails.head(2)
# Out:
#    trail_id                        name                   area_name  \
# 0  10020048     Harding Ice Field Trail  Kenai Fjords National Park
# 1  10236086  Mount Healy Overlook Trail        Denali National Park
#
#   state_name                               _geoloc  popularity     length  \
# 0     Alaska  {'lat': 60.18852, 'lng': -149.63156}     24.8931  15610.598
# 1     Alaska  {'lat': 63.73049, 'lng': -148.91968}     18.0311   6920.162
#
#    elevation_gain  difficulty_rating    route_type  avg_rating  num_reviews
# 0       1161.8976                  5  out and back         5.0          423
# 1        507.7968                  3  out and back         4.5          260

# %%
clean_test = clean_all_trails['area_name'].unique()
clean_test
print(len(clean_test))
# Out:
# 59

# %%
print(clean_all_trails[clean_all_trails['area_name']=="Death Valley National Park"])
# Out:
#       trail_id                             name                   area_name  \
# 255   10006688  Badwater Basin Salt Flats Trail  Death Valley National Park
# 268   10236017   Mesquite Flat Sand Dunes Trail  Death Valley National Park
# 287   10034011                  Zabriskie Point  Death Valley National Park
# 297   10027315               Dante's View Trail  Death Valley National Park
# 300   10033216             Telescope Peak Trail  Death Valley National Park
# ...        ...                              ...                         ...
# 919   10458560         Hunter Mountain OHV Road  Death Valley National Park
# 921   10461840              Death Valley Buttes  Death Valley National Park
# 1610  10261421                Titus Canyon Road  Death Valley National Park
# 1621  10270278              Rhyolite Ghost Town  Death Valley National Park
# 1630  10402715               Thimble Peak Trail  Death Valley National Park
#
#       state_name                                         _geoloc  popularity  \
# 255   California             {'lat': 36.23035, 'lng': -116.7668}     23.0844
# 268   California             {'lat': 36.60611, 'lng': -117.1151}     20.2433
# 287   California            {'lat': 36.42095, 'lng': -116.80986}     18.3978
# 297   California            {'lat': 36.22072, 'lng': -116.72648}     17.5667
# 300   California            {'lat': 36.22988, 'lng': -117.06829}     17.1872
# ...          ...                                             ...         ...
# 919   California            {'lat': 36.60175, 'lng': -117.46085}      0.8463
# 921   California  {'lat': 36.723910000000004, 'lng': -116.97807}      0.7015
# 1610      Nevada            {'lat': 36.85936, 'lng': -116.84565}     10.5062
# 1621      Nevada            {'lat': 36.89737, 'lng': -116.82951}      5.2404
# 1630      Nevada            {'lat': 36.82866, 'lng': -117.03255}      1.6462
#
#          length  elevation_gain  difficulty_rating      route_type  \
# 255    2896.812          2.7432                  1    out and back
# 268    4506.152         62.7888                  1    out and back
# 287     643.736         15.8496                  1    out and back
# 297    2574.944        109.7280                  1    out and back
# 300   19312.080       1012.8504                  5    out and back
# ...         ...             ...                ...             ...
# 919   17219.938        684.8856                  3  point to point
# 921    5954.558        448.9704                  5    out and back
# 1610  41842.840        736.7016                  1  point to point
# 1621   1770.274         35.9664                  1    out and back
# 1630   5149.888        501.7008                  3    out and back
#
#       avg_rating  num_reviews
# 255          4.5          259
# 268          4.5          176
# 287          4.5          147
# 297          4.5          102
# 300          4.5          101
# ...          ...          ...
# 919          5.0            1
# 921          0.0            0
# 1610         4.5           46
# 1621         4.0            9
# 1630         5.0            2
#
# [79 rows x 12 columns]

# %%
lat = []
lon = []
# For each row in a varible,
for row in clean_all_trails['_geoloc']:
    # Try to,
    try:
        # Split the row by comma and append
        # everything before the comma to lat
        lat.append(row.split(',')[0])
        # Split the row by comma and append
        # everything after the comma to lon
        lon.append(row.split(',')[1])
    # But if you get an error
    except:
        # append a missing value to lat
        lat.append(np.NaN)
        # append a missing value to lon
        lon.append(np.NaN)
# Create two new columns from lat and lon
clean_all_trails['trailhead_lat'] = lat
clean_all_trails['trailhead_long'] = lon

# %%
clean_all_trails = clean_all_trails.drop(columns=['_geoloc'])
clean_all_trails.head()
# Out:
#    trail_id                        name                   area_name  \
# 0  10020048     Harding Ice Field Trail  Kenai Fjords National Park
# 1  10236086  Mount Healy Overlook Trail        Denali National Park
# 2  10267857          Exit Glacier Trail  Kenai Fjords National Park
# 3  10236076        Horseshoe Lake Trail        Denali National Park
# 4  10236082          Triple Lakes Trail        Denali National Park
#
#   state_name  popularity     length  elevation_gain  difficulty_rating  \
# 0     Alaska     24.8931  15610.598       1161.8976                  5
# 1     Alaska     18.0311   6920.162        507.7968                  3
# 2     Alaska     17.7821   2896.812         81.9912                  1
# 3     Alaska     16.2674   3379.614        119.7864                  1
# 4     Alaska     12.5935  29772.790       1124.7120                  5
#
#      route_type  avg_rating  num_reviews     trailhead_lat  \
# 0  out and back         5.0          423  {'lat': 60.18852
# 1  out and back         4.5          260  {'lat': 63.73049
# 2  out and back         4.5          224  {'lat': 60.18879
# 3          loop         4.5          237  {'lat': 63.73661
# 4  out and back         4.5          110  {'lat': 63.73319
#
#         trailhead_long
# 0   'lng': -149.63156}
# 1   'lng': -148.91968}
# 2     'lng': -149.631}
# 3     'lng': -148.915}
# 4   'lng': -148.89682}

# %%
clean_trails_df = pd.DataFrame(clean_all_trails)
clean_trails_df.head()
# Out:
#    trail_id                        name                   area_name  \
# 0  10020048     Harding Ice Field Trail  Kenai Fjords National Park
# 1  10236086  Mount Healy Overlook Trail        Denali National Park
# 2  10267857          Exit Glacier Trail  Kenai Fjords National Park
# 3  10236076        Horseshoe Lake Trail        Denali National Park
# 4  10236082          Triple Lakes Trail        Denali National Park
#
#   state_name  popularity     length  elevation_gain  difficulty_rating  \
# 0     Alaska     24.8931  15610.598       1161.8976                  5
# 1     Alaska     18.0311   6920.162        507.7968                  3
# 2     Alaska     17.7821   2896.812         81.9912                  1
# 3     Alaska     16.2674   3379.614        119.7864                  1
# 4     Alaska     12.5935  29772.790       1124.7120                  5
#
#      route_type  avg_rating  num_reviews     trailhead_lat  \
# 0  out and back         5.0          423  {'lat': 60.18852
# 1  out and back         4.5          260  {'lat': 63.73049
# 2  out and back         4.5          224  {'lat': 60.18879
# 3          loop         4.5          237  {'lat': 63.73661
# 4  out and back         4.5          110  {'lat': 63.73319
#
#         trailhead_long
# 0   'lng': -149.63156}
# 1   'lng': -148.91968}
# 2     'lng': -149.631}
# 3     'lng': -148.915}
# 4   'lng': -148.89682}

# %%
cleaning_lat = {
    "{'lat':": ""
}

clean_trails_df = clean_trails_df.replace(cleaning_lat, regex=True)
clean_trails_df['trailhead_lat'] = clean_trails_df['trailhead_lat'].str.strip()

clean_trails_df.head()
# Out:
#    trail_id                        name                   area_name  \
# 0  10020048     Harding Ice Field Trail  Kenai Fjords National Park
# 1  10236086  Mount Healy Overlook Trail        Denali National Park
# 2  10267857          Exit Glacier Trail  Kenai Fjords National Park
# 3  10236076        Horseshoe Lake Trail        Denali National Park
# 4  10236082          Triple Lakes Trail        Denali National Park
#
#   state_name  popularity     length  elevation_gain  difficulty_rating  \
# 0     Alaska     24.8931  15610.598       1161.8976                  5
# 1     Alaska     18.0311   6920.162        507.7968                  3
# 2     Alaska     17.7821   2896.812         81.9912                  1
# 3     Alaska     16.2674   3379.614        119.7864                  1
# 4     Alaska     12.5935  29772.790       1124.7120                  5
#
#      route_type  avg_rating  num_reviews trailhead_lat       trailhead_long
# 0  out and back         5.0          423      60.18852   'lng': -149.63156}
# 1  out and back         4.5          260      63.73049   'lng': -148.91968}
# 2  out and back         4.5          224      60.18879     'lng': -149.631}
# 3          loop         4.5          237      63.73661     'lng': -148.915}
# 4  out and back         4.5          110      63.73319   'lng': -148.89682}

# %%
cleaning_lon = {
    "'lng':": "",
    "}": ""
}
clean_trails_df = clean_trails_df.replace(cleaning_lon, regex=True)
clean_trails_df['trailhead_long'] = clean_trails_df['trailhead_long'].str.strip()

clean_trails_df.head()
# Out:
#    trail_id                        name                   area_name  \
# 0  10020048     Harding Ice Field Trail  Kenai Fjords National Park
# 1  10236086  Mount Healy Overlook Trail        Denali National Park
# 2  10267857          Exit Glacier Trail  Kenai Fjords National Park
# 3  10236076        Horseshoe Lake Trail        Denali National Park
# 4  10236082          Triple Lakes Trail        Denali National Park
#
#   state_name  popularity     length  elevation_gain  difficulty_rating  \
# 0     Alaska     24.8931  15610.598       1161.8976                  5
# 1     Alaska     18.0311   6920.162        507.7968                  3
# 2     Alaska     17.7821   2896.812         81.9912                  1
# 3     Alaska     16.2674   3379.614        119.7864                  1
# 4     Alaska     12.5935  29772.790       1124.7120                  5
#
#      route_type  avg_rating  num_reviews trailhead_lat trailhead_long
# 0  out and back         5.0          423      60.18852     -149.63156
# 1  out and back         4.5          260      63.73049     -148.91968
# 2  out and back         4.5          224      60.18879       -149.631
# 3          loop         4.5          237      63.73661       -148.915
# 4  out and back         4.5          110      63.73319     -148.89682

# %%
clean_trails_df = clean_trails_df.rename(columns={"name": "trail_name",
                                                    "area_name": "national_park",
                                                    "state_name": "state",
                                                    "elevation_gain": "elevation",
                                                    "difficulty_rating": "difficulty",
                                                    "route_type": "route_type",
                                                    "avg_rating": "rating",
                                                   })
clean_trails_df.head()
# Out:
#    trail_id                  trail_name               national_park   state  \
# 0  10020048     Harding Ice Field Trail  Kenai Fjords National Park  Alaska
# 1  10236086  Mount Healy Overlook Trail        Denali National Park  Alaska
# 2  10267857          Exit Glacier Trail  Kenai Fjords National Park  Alaska
# 3  10236076        Horseshoe Lake Trail        Denali National Park  Alaska
# 4  10236082          Triple Lakes Trail        Denali National Park  Alaska
#
#    popularity     length  elevation  difficulty    route_type  rating  \
# 0     24.8931  15610.598  1161.8976           5  out and back     5.0
# 1     18.0311   6920.162   507.7968           3  out and back     4.5
# 2     17.7821   2896.812    81.9912           1  out and back     4.5
# 3     16.2674   3379.614   119.7864           1          loop     4.5
# 4     12.5935  29772.790  1124.7120           5  out and back     4.5
#
#    num_reviews trailhead_lat trailhead_long
# 0          423      60.18852     -149.63156
# 1          260      63.73049     -148.91968
# 2          224      60.18879       -149.631
# 3          237      63.73661       -148.915
# 4          110      63.73319     -148.89682

# %%
clean_trails_df['popularity'] = clean_trails_df['popularity'].round(1)
popularity_stats = clean_trails_df['popularity'].describe()
print(popularity_stats)
clean_trails_df.head()
# Out:
# count    3312.000000
# mean        8.955193
# std         8.139165
# min         0.000000
# 25%         3.800000
# 50%         6.600000
# 75%        11.300000
# max        84.600000
# Name: popularity, dtype: float64
#    trail_id                  trail_name               national_park   state  \
# 0  10020048     Harding Ice Field Trail  Kenai Fjords National Park  Alaska
# 1  10236086  Mount Healy Overlook Trail        Denali National Park  Alaska
# 2  10267857          Exit Glacier Trail  Kenai Fjords National Park  Alaska
# 3  10236076        Horseshoe Lake Trail        Denali National Park  Alaska
# 4  10236082          Triple Lakes Trail        Denali National Park  Alaska
#
#    popularity     length  elevation  difficulty    route_type  rating  \
# 0        24.9  15610.598  1161.8976           5  out and back     5.0
# 1        18.0   6920.162   507.7968           3  out and back     4.5
# 2        17.8   2896.812    81.9912           1  out and back     4.5
# 3        16.3   3379.614   119.7864           1          loop     4.5
# 4        12.6  29772.790  1124.7120           5  out and back     4.5
#
#    num_reviews trailhead_lat trailhead_long
# 0          423      60.18852     -149.63156
# 1          260      63.73049     -148.91968
# 2          224      60.18879       -149.631
# 3          237      63.73661       -148.915
# 4          110      63.73319     -148.89682

# %%
clean_trails_df['elevation'] = clean_trails_df['elevation'].round(1)
elevation_stats = clean_trails_df['elevation'].describe()
print(elevation_stats)
clean_trails_df.head()
# Out:
# count     3312.000000
# mean       641.988104
# std        901.581984
# min          0.000000
# 25%        117.675000
# 50%        360.450000
# 75%        834.375000
# max      14029.900000
# Name: elevation, dtype: float64
#    trail_id                  trail_name               national_park   state  \
# 0  10020048     Harding Ice Field Trail  Kenai Fjords National Park  Alaska
# 1  10236086  Mount Healy Overlook Trail        Denali National Park  Alaska
# 2  10267857          Exit Glacier Trail  Kenai Fjords National Park  Alaska
# 3  10236076        Horseshoe Lake Trail        Denali National Park  Alaska
# 4  10236082          Triple Lakes Trail        Denali National Park  Alaska
#
#    popularity     length  elevation  difficulty    route_type  rating  \
# 0        24.9  15610.598     1161.9           5  out and back     5.0
# 1        18.0   6920.162      507.8           3  out and back     4.5
# 2        17.8   2896.812       82.0           1  out and back     4.5
# 3        16.3   3379.614      119.8           1          loop     4.5
# 4        12.6  29772.790     1124.7           5  out and back     4.5
#
#    num_reviews trailhead_lat trailhead_long
# 0          423      60.18852     -149.63156
# 1          260      63.73049     -148.91968
# 2          224      60.18879       -149.631
# 3          237      63.73661       -148.915
# 4          110      63.73319     -148.89682

# %%
length_stats = clean_trails_df['length'].describe()
print(length_stats)
# Out:
# count      3312.000000
# mean      17681.408470
# std       25499.875752
# min           0.000000
# 25%        4506.152000
# 50%       10621.644000
# 75%       21404.222000
# max      529794.728000
# Name: length, dtype: float64

# %%
#moving decimal to make values in kilometers
clean_trails_df['length'] = clean_trails_df['length'].div(1000)
clean_trails_df.head()
# Out:
#    trail_id                  trail_name               national_park   state  \
# 0  10020048     Harding Ice Field Trail  Kenai Fjords National Park  Alaska
# 1  10236086  Mount Healy Overlook Trail        Denali National Park  Alaska
# 2  10267857          Exit Glacier Trail  Kenai Fjords National Park  Alaska
# 3  10236076        Horseshoe Lake Trail        Denali National Park  Alaska
# 4  10236082          Triple Lakes Trail        Denali National Park  Alaska
#
#    popularity     length  elevation  difficulty    route_type  rating  \
# 0        24.9  15.610598     1161.9           5  out and back     5.0
# 1        18.0   6.920162      507.8           3  out and back     4.5
# 2        17.8   2.896812       82.0           1  out and back     4.5
# 3        16.3   3.379614      119.8           1          loop     4.5
# 4        12.6  29.772790     1124.7           5  out and back     4.5
#
#    num_reviews trailhead_lat trailhead_long
# 0          423      60.18852     -149.63156
# 1          260      63.73049     -148.91968
# 2          224      60.18879       -149.631
# 3          237      63.73661       -148.915
# 4          110      63.73319     -148.89682

# %%
#changing length value of kilometers to miles
clean_trails_df['length'] = clean_trails_df['length'].div(1.609)
clean_trails_df.head()
# Out:
#    trail_id                  trail_name               national_park   state  \
# 0  10020048     Harding Ice Field Trail  Kenai Fjords National Park  Alaska
# 1  10236086  Mount Healy Overlook Trail        Denali National Park  Alaska
# 2  10267857          Exit Glacier Trail  Kenai Fjords National Park  Alaska
# 3  10236076        Horseshoe Lake Trail        Denali National Park  Alaska
# 4  10236082          Triple Lakes Trail        Denali National Park  Alaska
#
#    popularity     length  elevation  difficulty    route_type  rating  \
# 0        24.9   9.702050     1161.9           5  out and back     5.0
# 1        18.0   4.300909      507.8           3  out and back     4.5
# 2        17.8   1.800380       82.0           1  out and back     4.5
# 3        16.3   2.100444      119.8           1          loop     4.5
# 4        12.6  18.503909     1124.7           5  out and back     4.5
#
#    num_reviews trailhead_lat trailhead_long
# 0          423      60.18852     -149.63156
# 1          260      63.73049     -148.91968
# 2          224      60.18879       -149.631
# 3          237      63.73661       -148.915
# 4          110      63.73319     -148.89682

# %%
clean_trails_df['length'] = clean_trails_df['length'].round(1)
length_stats = clean_trails_df['length'].describe()
print(length_stats)
clean_trails_df.head()
# Out:
# count    3312.000000
# mean       10.986775
# std        15.845534
# min         0.000000
# 25%         2.800000
# 50%         6.600000
# 75%        13.300000
# max       329.300000
# Name: length, dtype: float64
#    trail_id                  trail_name               national_park   state  \
# 0  10020048     Harding Ice Field Trail  Kenai Fjords National Park  Alaska
# 1  10236086  Mount Healy Overlook Trail        Denali National Park  Alaska
# 2  10267857          Exit Glacier Trail  Kenai Fjords National Park  Alaska
# 3  10236076        Horseshoe Lake Trail        Denali National Park  Alaska
# 4  10236082          Triple Lakes Trail        Denali National Park  Alaska
#
#    popularity  length  elevation  difficulty    route_type  rating  \
# 0        24.9     9.7     1161.9           5  out and back     5.0
# 1        18.0     4.3      507.8           3  out and back     4.5
# 2        17.8     1.8       82.0           1  out and back     4.5
# 3        16.3     2.1      119.8           1          loop     4.5
# 4        12.6    18.5     1124.7           5  out and back     4.5
#
#    num_reviews trailhead_lat trailhead_long
# 0          423      60.18852     -149.63156
# 1          260      63.73049     -148.91968
# 2          224      60.18879       -149.631
# 3          237      63.73661       -148.915
# 4          110      63.73319     -148.89682

# %%
clean_trails_df.to_csv('Resources/clean_trails_df.csv', index=False, header=True)

# %%
trails_df = clean_trails_df.drop(columns=['popularity', 'length', 'elevation', 'difficulty', 'route_type', 'rating', 'num_reviews'])
trails_df.head()
# Out:
#    trail_id                  trail_name               national_park   state  \
# 0  10020048     Harding Ice Field Trail  Kenai Fjords National Park  Alaska
# 1  10236086  Mount Healy Overlook Trail        Denali National Park  Alaska
# 2  10267857          Exit Glacier Trail  Kenai Fjords National Park  Alaska
# 3  10236076        Horseshoe Lake Trail        Denali National Park  Alaska
# 4  10236082          Triple Lakes Trail        Denali National Park  Alaska
#
#   trailhead_lat trailhead_long
# 0      60.18852     -149.63156
# 1      63.73049     -148.91968
# 2      60.18879       -149.631
# 3      63.73661       -148.915
# 4      63.73319     -148.89682

# %%
trails_df.to_csv('Output/trails.csv', index=False, header=True)
