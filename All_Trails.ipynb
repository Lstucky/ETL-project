# %%
import pandas as pd

# %%
csv_path = "Resources/AllTrails_data_nationalpark.csv"
all_trails_df = pd.read_csv(csv_path)
all_trails_df.head()
# Out:
#    trail_id                        name                   area_name  \
# 0  10020048     Harding Ice Field Trail  Kenai Fjords National Park
# 1  10236086  Mount Healy Overlook Trail        Denali National Park
# 2  10267857          Exit Glacier Trail  Kenai Fjords National Park
# 3  10236076        Horseshoe Lake Trail        Denali National Park
# 4  10236082          Triple Lakes Trail        Denali National Park
#
#               city_name state_name   country_name  \
# 0                Seward     Alaska  United States
# 1  Denali National Park     Alaska  United States
# 2                Seward     Alaska  United States
# 3  Denali National Park     Alaska  United States
# 4  Denali National Park     Alaska  United States
#
#                                 _geoloc  popularity     length  \
# 0  {'lat': 60.18852, 'lng': -149.63156}     24.8931  15610.598
# 1  {'lat': 63.73049, 'lng': -148.91968}     18.0311   6920.162
# ...

# %%
all_trails_df['name'].value_counts()
# Out:
# Black Canyon Trail                             3
# Bubbs Creek Trail                              2
# Irely Lake Trail                               2
# Mills Lake via Glacier Gorge Trail             2
# Clear Creek Trail                              2
#                                               ..
# Bishop Pass Trail                              1
# Norada Falls to Mazama Ridge Loop              1
# Gaylor Lakes Trail                             1
# Biscuit Basin Interpretive Trail               1
# Cove of Caves via Parade of Elephants Trail    1
# Name: name, Length: 3288, dtype: int64

# %%
country = all_trails_df['country_name'].value_counts()
state = all_trails_df['state_name'].value_counts()
print(country)
print(state)
# Out:
# United States    3264
# Hawaii             49
# Name: country_name, dtype: int64
# California        707
# Washington        320
# Wyoming           311
# Utah              292
# Colorado          262
# Virginia          191
# Maine             179
# Tennessee         175
# Arizona           174
# Montana           151
# North Carolina    118
# Texas              94
# Ohio               50
# Hawaii             35
# Florida            31
# Alaska             29
# Kentucky           28
# Nevada             25
# North Dakota       23
# Oregon             22
# South Dakota       20
# Indiana            16
# Arkansas           16
# Maui               14
# New Mexico          8
# South Carolina      8
# Minnesota           7
# Michigan            4
# Missouri            2
# Georgia             1
# Name: state_name, dtype: int64

# %%
trails_unique = all_trails_df['area_name'].unique()
print(len(trails_unique))
trails_unique
# Out:
# 60
# array(['Kenai Fjords National Park', 'Denali National Park',
#        'Glacier Bay National Park', 'Katmai National Park',
#        'Grand Canyon National Park', 'Saguaro National Park',
#        'Petrified Forest National Park', 'Hot Springs National Park',
#        'Yosemite National Park', 'Sequoia National Park',
#        'Joshua Tree National Park', 'Lassen Volcanic National Park',
#        'Kings Canyon National Park', 'Pinnacles National Park',
#        'Death Valley National Park', 'Redwood National Park',
#        'Channel Islands National Park', 'Rocky Mountain National Park',
#        'Great Sand Dunes National Park and Preserve',
#        'Mesa Verde National Park',
#        'Black Canyon of the Gunnison National Park',
#        'Everglades National Park', 'Fort Pickens National Park',
#        'Biscayne National Park', 'Dry Tortugas National Park',
#        'Clayton Co International Park, Jonesboro GA',
# ...

# %%
all_trails_df['area_name'].value_counts()
# Out:
# Great Smoky Mountains National Park                293
# Yosemite National Park                             242
# Yellowstone National Park                          228
# Rocky Mountain National Park                       207
# Shenandoah National Park                           187
# Acadia National Park                               179
# Olympic National Park                              170
# Glacier National Park                              132
# Mount Rainier National Park                        130
# Joshua Tree National Park                          108
# Grand Teton National Park                          102
# Grand Canyon National Park                          99
# Zion National Park                                  94
# Sequoia National Park                               90
# Death Valley National Park                          79
# Canyonlands National Park                           77
# Big Bend National Park                              70
# ...

# %%
features = all_trails_df['features'].value_counts()
print(features)
# Out:
# ['dogs-no', 'forest', 'views', 'wild-flowers', 'wildlife']                                                                   175
# ['dogs-no', 'views', 'wild-flowers', 'wildlife']                                                                             121
# ['dogs-no', 'views']                                                                                                         114
# ['dogs-no', 'forest', 'lake', 'views', 'wild-flowers', 'wildlife']                                                           103
# ['dogs-no', 'forest', 'river', 'views', 'wild-flowers', 'wildlife']                                                           78
#                                                                                                                             ...
# ['dogs-no', 'lake', 'river', 'views', 'waterfall', 'wildlife']                                                                 1
# ...

# %%
activities = all_trails_df['activities'].value_counts()
print(activities)
# Out:
# ['birding', 'hiking', 'nature-trips', 'walking']                                                                                  450
# ['birding', 'hiking', 'nature-trips', 'trail-running', 'walking']                                                                 249
# ['birding', 'hiking', 'nature-trips']                                                                                             189
# ['hiking']                                                                                                                        156
# ['hiking', 'nature-trips', 'walking']                                                                                             127
#                                                                                                                                  ...
# ['hiking', 'nature-trips', 'snowshoeing', 'trail-running', 'walking', 'cross-country-skiing']                                       1
# ...

# %%
all_trails_df.head()
# Out:
#    trail_id                        name                   area_name  \
# 0  10020048     Harding Ice Field Trail  Kenai Fjords National Park
# 1  10236086  Mount Healy Overlook Trail        Denali National Park
# 2  10267857          Exit Glacier Trail  Kenai Fjords National Park
# 3  10236076        Horseshoe Lake Trail        Denali National Park
# 4  10236082          Triple Lakes Trail        Denali National Park
#
#               city_name state_name   country_name  \
# 0                Seward     Alaska  United States
# 1  Denali National Park     Alaska  United States
# 2                Seward     Alaska  United States
# 3  Denali National Park     Alaska  United States
# 4  Denali National Park     Alaska  United States
#
#                                 _geoloc  popularity     length  \
# 0  {'lat': 60.18852, 'lng': -149.63156}     24.8931  15610.598
# 1  {'lat': 63.73049, 'lng': -148.91968}     18.0311   6920.162
# ...

# %%
clean_all_trails = all_trails_df.drop(columns=['trail_id', 'city_name', 'country_name', 'units'])
clean_all_trails.head()
# Out:
#                          name                   area_name state_name  \
# 0     Harding Ice Field Trail  Kenai Fjords National Park     Alaska
# 1  Mount Healy Overlook Trail        Denali National Park     Alaska
# 2          Exit Glacier Trail  Kenai Fjords National Park     Alaska
# 3        Horseshoe Lake Trail        Denali National Park     Alaska
# 4          Triple Lakes Trail        Denali National Park     Alaska
#
#                                 _geoloc  popularity     length  \
# 0  {'lat': 60.18852, 'lng': -149.63156}     24.8931  15610.598
# 1  {'lat': 63.73049, 'lng': -148.91968}     18.0311   6920.162
# 2    {'lat': 60.18879, 'lng': -149.631}     17.7821   2896.812
# 3    {'lat': 63.73661, 'lng': -148.915}     16.2674   3379.614
# 4  {'lat': 63.73319, 'lng': -148.89682}     12.5935  29772.790
#
#    elevation_gain  difficulty_rating    route_type  visitor_usage  avg_rating  \
# 0       1161.8976                  5  out and back            3.0         5.0
# ...

# %%
clean_all_trails = clean_all_trails.rename(columns={"name": "Trail Name",
                                                    "area_name": "National Park",
                                                    "state_name": "State",
                                                    "_geoloc": "TH Coordinates",
                                                    "popularity": "All Trails Popularity",
                                                    "length": "Trail Length",
                                                    "elevation_gain": "Elevation Gain",
                                                    "difficulty_rating": "All Trails Difficulty Rating",
                                                    "route_type": "Route Type",
                                                    "visitor_usage": "All Trails Visitor Usage",
                                                    "avg_rating": "All Trails Average Rating",
                                                    "num_reviews": "All Trails Total Reviews",
                                                    "features": "Trail Features",
                                                    "activities": "Activities"
                                                   })
clean_all_trails.head()
# Out:
#                    Trail Name               National Park   State  \
# 0     Harding Ice Field Trail  Kenai Fjords National Park  Alaska
# 1  Mount Healy Overlook Trail        Denali National Park  Alaska
# 2          Exit Glacier Trail  Kenai Fjords National Park  Alaska
# 3        Horseshoe Lake Trail        Denali National Park  Alaska
# 4          Triple Lakes Trail        Denali National Park  Alaska
#
#                          TH Coordinates  All Trails Popularity  Trail Length  \
# 0  {'lat': 60.18852, 'lng': -149.63156}                24.8931     15610.598
# 1  {'lat': 63.73049, 'lng': -148.91968}                18.0311      6920.162
# 2    {'lat': 60.18879, 'lng': -149.631}                17.7821      2896.812
# 3    {'lat': 63.73661, 'lng': -148.915}                16.2674      3379.614
# 4  {'lat': 63.73319, 'lng': -148.89682}                12.5935     29772.790
#
#    Elevation Gain  All Trails Difficulty Rating    Route Type  \
# ...
