# %%
import pandas as pd

# %%
csv_path = "Resources/nps_acres.csv"
nps_acres_df = pd.read_csv(csv_path)
nps_acres_df.head()
# Out:
#   Park Code               Park Name State   Acres  Latitude  Longitude
# 0      ACAD    Acadia National Park    ME   47390     44.35     -68.21
# 1      ARCH    Arches National Park    UT   76519     38.68    -109.57
# 2      BADL  Badlands National Park    SD  242756     43.75    -102.50
# 3      BIBE  Big Bend National Park    TX  801163     29.25    -103.25
# 4      BISC  Biscayne National Park    FL  172924     25.65     -80.08

# %%
nps_unique = nps_acres_df['Park Name'].unique()
print(len(nps_unique))
print(nps_unique)
# Out:
# 56
# ['Acadia National Park' 'Arches National Park' 'Badlands National Park'
#  'Big Bend National Park' 'Biscayne National Park'
#  'Black Canyon of the Gunnison National Park' 'Bryce Canyon National Park'
#  'Canyonlands National Park' 'Capitol Reef National Park'
#  'Carlsbad Caverns National Park' 'Channel Islands National Park'
#  'Congaree National Park' 'Crater Lake National Park'
#  'Cuyahoga Valley National Park' 'Denali National Park and Preserve'
#  'Death Valley National Park' 'Dry Tortugas National Park'
#  'Everglades National Park'
#  'Gates Of The Arctic National Park and Preserve' 'Glacier National Park'
#  'Glacier Bay National Park and Preserve' 'Great Basin National Park'
#  'Grand Canyon National Park'
#  'Great Sand Dunes National Park and Preserve'
#  'Great Smoky Mountains National Park' 'Grand Teton National Park'
#  'Guadalupe Mountains National Park' 'Haleakala National Park'
#  'Hawaii Volcanoes National Park' 'Hot Springs National Park'
# ...

# %%
nps_acres_df['Park Name'].value_counts()
nps_acres_df['Park Name'].sort_values()
# Out:
# 0                               Acadia National Park
# 1                               Arches National Park
# 2                             Badlands National Park
# 3                             Big Bend National Park
# 4                             Biscayne National Park
# 5         Black Canyon of the Gunnison National Park
# 6                         Bryce Canyon National Park
# 7                          Canyonlands National Park
# 8                         Capitol Reef National Park
# 9                     Carlsbad Caverns National Park
# 10                     Channel Islands National Park
# 11                            Congaree National Park
# 12                         Crater Lake National Park
# 13                     Cuyahoga Valley National Park
# 15                        Death Valley National Park
# 14                 Denali National Park and Preserve
# 16                        Dry Tortugas National Park
# 17                          Everglades National Park
# ...

# %%
clean_nps_acres = nps_acres_df.replace({
    'AL': 'Alabama',
    'AK': 'Alaska',
    'AZ': 'Arizona',
    'AR': 'Arkansas',
    'CA': 'California',
    'CO': 'Colorado',
    'CT': 'Connecticut',
    'DE': 'Delaware',
    'FL': 'Florida',
    'GA': 'Georgia',
    'HI': 'Hawaii',
    'ID': 'Idaho',
    'IL': 'Illinois',
    'IN': 'Indiana',
    'IA': 'Iowa',
    'KS': 'Kansas',
    'KY': 'Kentucky',
    'LA': 'Louisiana',
    'ME': 'Maine',
    'MD': 'Maryland',
    'MA': 'Massachusetts',
    'MI': 'Michigan',
    'MN': 'Minnesota',
    'MS': 'Mississippi',
    'MO': 'Missouri',
    'MT': 'Montana',
    'NE': 'Nebraska',
    'NV': 'Nevada',
    'NH': 'New Hampshire',
    'NJ': 'New Jersey',
    'NM': 'New Mexico',
    'NY': 'New York',
    'NC': 'North Carolina',
    'ND': 'North Dakota',
    'OH': 'Ohio',
    'OK': 'Oklahoma',
    'OR': 'Oregon',
    'PA': 'Pennsylvania',
    'RI': 'Rhode Island',
    'SC': 'South Carolina',
    'SD': 'South Dakota',
    'TN': 'Tennessee',
    'TX': 'Texas',
    'UT': 'Utah',
    'VT': 'Vermont',
    'VA': 'Virginia',
    'WA': 'Washington',
    'WV': 'West Virginia',
    'WI': 'Wisconsin',
    'WY': 'Wyoming'
})

# %%
clean_nps_acres.head()
# Out:
#   Park Code               Park Name         State   Acres  Latitude  Longitude
# 0      ACAD    Acadia National Park         Maine   47390     44.35     -68.21
# 1      ARCH    Arches National Park          Utah   76519     38.68    -109.57
# 2      BADL  Badlands National Park  South Dakota  242756     43.75    -102.50
# 3      BIBE  Big Bend National Park         Texas  801163     29.25    -103.25
# 4      BISC  Biscayne National Park       Florida  172924     25.65     -80.08

# %%
clean_nps_acres = clean_nps_acres.rename(columns={"Park Code": "park_code", "Park Name": "national_park", "State": "state", "Acres": "acres", "Latitude": 'latitude', "Longitude":"longitude"})
clean_nps_acres.head()
# Out:
#   park_code           national_park         state   acres  latitude  longitude
# 0      ACAD    Acadia National Park         Maine   47390     44.35     -68.21
# 1      ARCH    Arches National Park          Utah   76519     38.68    -109.57
# 2      BADL  Badlands National Park  South Dakota  242756     43.75    -102.50
# 3      BIBE  Big Bend National Park         Texas  801163     29.25    -103.25
# 4      BISC  Biscayne National Park       Florida  172924     25.65     -80.08

# %%
#DEVA park code came up while importing to sql as having a null for all other columns when doing a left join
#and when tried with outer join
print(clean_nps_acres[clean_nps_acres['park_code']=="DEVA"])
# Out:
#    park_code               national_park   state    acres  latitude  longitude
# 15      DEVA  Death Valley National Park  CA, NV  4740912     36.24    -116.82

# %%
clean_nps_acres['state'].value_counts()
# Out:
# Alaska            8
# California        7
# Utah              5
# Colorado          4
# Arizona           3
# Florida           3
# Washington        3
# Hawaii            2
# South Dakota      2
# Texas             2
# Virginia          1
# Minnesota         1
# Wyoming           1
# Ohio              1
# Kentucky          1
# Oregon            1
# WY, MT, ID        1
# North Dakota      1
# Michigan          1
# South Carolina    1
# TN, NC            1
# Maine             1
# Montana           1
# Arkansas          1
# New Mexico        1
# Nevada            1
# CA, NV            1
# Name: state, dtype: int64

# %%
nps_replace = {
    "and Preserve": "",
    "The ": "the ",
    "Of ": "of "
}
clean_nps_acres = clean_nps_acres.replace(nps_replace, regex=True)
clean_nps_acres['national_park'] = clean_nps_acres['national_park'].str.strip()
clean_nps_acres['national_park'].unique()
# Out:
# array(['Acadia National Park', 'Arches National Park',
#        'Badlands National Park', 'Big Bend National Park',
#        'Biscayne National Park',
#        'Black Canyon of the Gunnison National Park',
#        'Bryce Canyon National Park', 'Canyonlands National Park',
#        'Capitol Reef National Park', 'Carlsbad Caverns National Park',
#        'Channel Islands National Park', 'Congaree National Park',
#        'Crater Lake National Park', 'Cuyahoga Valley National Park',
#        'Denali National Park', 'Death Valley National Park',
#        'Dry Tortugas National Park', 'Everglades National Park',
#        'Gates of the Arctic National Park', 'Glacier National Park',
#        'Glacier Bay National Park', 'Great Basin National Park',
#        'Grand Canyon National Park', 'Great Sand Dunes National Park',
#        'Great Smoky Mountains National Park', 'Grand Teton National Park',
#        'Guadalupe Mountains National Park', 'Haleakala National Park',
# ...

# %%
nps_df = pd.DataFrame(clean_nps_acres)
nps_df.head()
# Out:
#   park_code           national_park         state   acres  latitude  longitude
# 0      ACAD    Acadia National Park         Maine   47390     44.35     -68.21
# 1      ARCH    Arches National Park          Utah   76519     38.68    -109.57
# 2      BADL  Badlands National Park  South Dakota  242756     43.75    -102.50
# 3      BIBE  Big Bend National Park         Texas  801163     29.25    -103.25
# 4      BISC  Biscayne National Park       Florida  172924     25.65     -80.08

# %%
nps_df.to_csv('Resources/nps_df.csv', index=False, header=True)

# %%
csv_path = "Resources/clean_trails_df.csv"
clean_trails_df = pd.read_csv(csv_path)
clean_trails_df.head()
# Out:
#    trail_id                  trail_name               national_park   state  \
# 0  10020048     Harding Ice Field Trail  Kenai Fjords National Park  Alaska
# 1  10236086  Mount Healy Overlook Trail        Denali National Park  Alaska
# 2  10267857          Exit Glacier Trail  Kenai Fjords National Park  Alaska
# 3  10236076        Horseshoe Lake Trail        Denali National Park  Alaska
# 4  10236082          Triple Lakes Trail        Denali National Park  Alaska
#
#    popularity  length  elevation  difficulty    route_type  rating  \
# 0        24.9     9.7     1161.9           5  out and back     5.0
# 1        18.0     4.3      507.8           3  out and back     4.5
# 2        17.8     1.8       82.0           1  out and back     4.5
# 3        16.3     2.1      119.8           1          loop     4.5
# 4        12.6    18.5     1124.7           5  out and back     4.5
#
#    num_reviews  trailhead_lat  trailhead_long
# 0          423       60.18852      -149.63156
# ...

# %%
nps_park_diff = set(nps_df.national_park).difference(clean_trails_df.national_park)
print(nps_park_diff)
# Out:
# {'Gates of the Arctic National Park', 'Great Sand Dunes National Park', 'Wrangell - St Elias National Park', 'Sequoia and Kings Canyon National Parks', 'Kobuk Valley National Park', 'Lake Clark National Park'}

# %%
trails_park_diff = set(clean_trails_df.national_park).difference(nps_df.national_park)
print(trails_park_diff)
# Out:
# {'Great Sand Dunes National Park and Preserve', 'Fort Hunt National Park', 'Congaree National Park Wilderness', 'Kings Canyon National Park', 'Gateway Arch National Park', 'Wolf Trap National Park for the Performing Arts', 'Indiana Dunes National Park', 'Fort Pickens National Park', 'Sequoia National Park'}

# %%
merge_clean_trails = pd.DataFrame.merge(nps_df, clean_trails_df, how='inner')
merge_clean_trails.head()
# Out:
#   park_code         national_park  state  acres  latitude  longitude  \
# 0      ACAD  Acadia National Park  Maine  47390     44.35     -68.21
# 1      ACAD  Acadia National Park  Maine  47390     44.35     -68.21
# 2      ACAD  Acadia National Park  Maine  47390     44.35     -68.21
# 3      ACAD  Acadia National Park  Maine  47390     44.35     -68.21
# 4      ACAD  Acadia National Park  Maine  47390     44.35     -68.21
#
#    trail_id                                 trail_name  popularity  length  \
# 0  10006208                     The Beehive Loop Trail        43.9     1.4
# 1  10006042                 Cadillac North Ridge Trail        34.8     4.0
# 2  10241910                Jordan Pond Full Loop Trail        31.1     3.4
# 3  10260660  Ocean Path and Gorham Mountain Loop Trail        30.5     3.1
# 4  10010417   Cadillac Mountain South Ridge Trail Loop        28.7     7.5
#
#    elevation  difficulty    route_type  rating  num_reviews  trailhead_lat  \
# ...

# %%
unique_parks = merge_clean_trails['national_park'].unique()
unique_parks
len(unique_parks)
# Out:
# 46

# %%
merge_clean_trails.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2508 entries, 0 to 2507
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   park_code       2508 non-null   object
#  1   national_park   2508 non-null   object
#  2   state           2508 non-null   object
#  3   acres           2508 non-null   int64
#  4   latitude        2508 non-null   float64
#  5   longitude       2508 non-null   float64
#  6   trail_id        2508 non-null   int64
#  7   trail_name      2508 non-null   object
#  8   popularity      2508 non-null   float64
#  9   length          2508 non-null   float64
#  10  elevation       2508 non-null   float64
#  11  difficulty      2508 non-null   int64
#  12  route_type      2508 non-null   object
#  13  rating          2508 non-null   float64
#  14  num_reviews     2508 non-null   int64
#  15  trailhead_lat   2508 non-null   float64
#  16  trailhead_long  2508 non-null   float64
# ...

# %%
merge_clean_trails['state'].value_counts()
# Out:
# California        480
# Washington        320
# Utah              292
# Colorado          248
# Virginia          187
# Maine             179
# Arizona           174
# Montana           132
# Wyoming           102
# Texas              94
# Ohio               50
# Hawaii             35
# Florida            29
# Alaska             29
# Kentucky           28
# North Dakota       23
# Oregon             22
# Nevada             22
# South Dakota       20
# Arkansas           16
# New Mexico          8
# Minnesota           7
# South Carolina      7
# Michigan            4
# Name: state, dtype: int64

# %%
merge_clean_trails
# Out:
#      park_code         national_park  state   acres  latitude  longitude  \
# 0         ACAD  Acadia National Park  Maine   47390     44.35     -68.21
# 1         ACAD  Acadia National Park  Maine   47390     44.35     -68.21
# 2         ACAD  Acadia National Park  Maine   47390     44.35     -68.21
# 3         ACAD  Acadia National Park  Maine   47390     44.35     -68.21
# 4         ACAD  Acadia National Park  Maine   47390     44.35     -68.21
# ...        ...                   ...    ...     ...       ...        ...
# 2503      ZION    Zion National Park   Utah  146598     37.30    -113.05
# 2504      ZION    Zion National Park   Utah  146598     37.30    -113.05
# 2505      ZION    Zion National Park   Utah  146598     37.30    -113.05
# 2506      ZION    Zion National Park   Utah  146598     37.30    -113.05
# 2507      ZION    Zion National Park   Utah  146598     37.30    -113.05
#
#       trail_id                                         trail_name  popularity  \
# ...

# %%
trail_stats = merge_clean_trails.drop(columns=['national_park', 'state', 'acres', 'latitude', 'longitude', 'trail_name', 'trailhead_lat', 'trailhead_long'])
trail_stats.head()
# Out:
#   park_code  trail_id  popularity  length  elevation  difficulty  \
# 0      ACAD  10006208        43.9     1.4      148.7           5
# 1      ACAD  10006042        34.8     4.0      340.8           3
# 2      ACAD  10241910        31.1     3.4       29.0           3
# 3      ACAD  10260660        30.5     3.1      182.0           3
# 4      ACAD  10010417        28.7     7.5      684.9           5
#
#      route_type  rating  num_reviews
# 0          loop     5.0         1123
# 1  out and back     4.5          679
# 2          loop     4.5          578
# 3          loop     4.5          343
# 4          loop     4.5          426

# %%
trail_stats.to_csv('Output/trail_stats.csv', index=False, header=True)
